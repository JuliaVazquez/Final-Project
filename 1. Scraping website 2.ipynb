# %%
from random import randint

# %%
from bs4 import BeautifulSoup
import requests
import random
from time import sleep
import pandas as pd
from pandas.io.json import json_normalize

# %%
    response = requests.get(
    "https://www.vinoseleccion.com/tipos-de-vino/vino-tinto",
    headers= {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0"
    }
)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Strict//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-strict.dtd">
#
# <html lang="es" xml:lang="es" xmlns="https://www.w3.org/1999/xhtml">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Vino Tinto</title>
# <meta content="vinoseleccion, vino tinto" name="keywords"/>
# <meta content="Los vinos tintos son los vinos obtenidos del mosto de uvas tintas, sometidos a un proceso de elaboración que permite transmitir al mosto la materia colorante contenida en los hollejos de las uvas.
#
# Fundamentalmente, los tintos de pueden obtener mediante dos procesos distintos de elaboración. El más extendido es el método tradicional: la uva se somete a los procesos de despalillado y estrujado y, a continuación, realiza un proceso de maceración-fermentación alcohólica, rematada con una segunda fermentación (llamada ‘maloláctica’) que suaviza y mejora las cualidades del vino. El otro método de elaboración de tintos es el denominado de maceración carbónica, consistente en encubar directamente el racimo sin despalillar. De este modo, tras un aporte de gas carbónico, se produce una fermentación intracelular. A continuación, se prensan las uvas que todavía están enteras y se sigue el método de elaboración tradicional.
#
# El color del vino depende de factores como las variedades de uva empleadas, la forma en que se ha elaborado o su edad. Las tonalidades de los tintos van desde el rojo claro hasta el negro: rojo claro, rojo violeta, rojo cereza, rojo rubí, rojo sangre, rojo anaranjado, teja, carmín, rubí, granate, bermellón, púrpura, violáceo, rojo picota, picota madura, rojo negro.
# " name="description"/>
# <meta content="INDEX,FOLLOW" name="robots"/>
# <meta content="initial-scale = 1.0,maximum-scale = 1.0" name="viewport"/>
# <link href="https://www.vinoseleccion.com/media/favicon/default/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/media/favicon/default/favicon-apple.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://www.vinoseleccion.com/media/favicon/default/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <!--[if lt IE 7]>
# <script type="text/javascript">
# //<![CDATA[
#     var BLANK_URL = 'https://www.vinoseleccion.com/js/blank.html';
#     var BLANK_IMG = 'https://www.vinoseleccion.com/js/spacer.gif';
# //]]>
# </script>
# <![endif]-->
# <meta content="" property="og:title" tinto"="" vino=""/>
# <meta content="article" property="og:type"/>
# <meta content="" https:="" property="og:url" tipos-de-vino="" vino-tinto"="" www.vinoseleccion.com=""/>
# <meta "="" (llamada="" a="" al="" alcohólica,="" anaranjado,="" aporte="" bermellón,="" carbónica,="" carbónico,="" carmín,="" cereza,="" claro="" claro,="" color="" colorante="" como="" con="" consistente="" contenida="" content="" continuación,="" cualidades="" de="" del="" denominado="" depende="" desde="" despalillado="" despalillar.="" directamente="" distintos="" dos="" edad.="" el="" elaboración="" elaboración.="" elaborado="" empleadas,="" en="" encubar="" enteras="" es="" este="" estrujado="" están="" extendido="" factores="" fermentación="" forma="" fundamentalmente,="" gas="" granate,="" ha="" hasta="" hollejos="" intracelular.="" la="" las="" los="" maceración="" maceración-fermentación="" madura,="" materia="" mediante="" mejora="" modo,="" mosto="" más="" método="" negro.="" negro:="" o="" obtener="" obtenidos="" otro="" permite="" picota="" picota,="" prensan="" proceso="" procesos="" produce="" property="og:description" pueden="" púrpura,="" que="" racimo="" realiza="" rematada="" rojo="" rubí,="" sangre,="" se="" segunda="" sigue="" sin="" somete="" sometidos="" son="" su="" suaviza="" teja,="" tintas,="" tintos="" todavía="" tonalidades="" tradicional.="" tradicional:="" transmitir="" tras="" un="" una="" uva="" uvas="" uvas.="" van="" variedades="" vino="" vino.="" vinos="" violeta,="" violáceo,="" y="" y,="" ‘maloláctica’)=""/>
# <meta content="Vinoseleccion" property="og:site_name"/>
# <link href="https://www.vinoseleccion.com/media/css_secure/d506db08aad826f2e2472ad8370e5d92.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.vinoseleccion.com/media/css_secure/0609200713a71c2649f67f10bba3d42d.css" media="print" rel="stylesheet" type="text/css"/>
# <script src="https://www.vinoseleccion.com/js/jquery/jquery.min.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/prototype/prototype.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/lib/ccard.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/prototype/validation.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/scriptaculous/builder.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/scriptaculous/effects.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/scriptaculous/dragdrop.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/scriptaculous/controls.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/scriptaculous/slider.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/varien/js.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/varien/form.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/varien/menu.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/mage/translate.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/mage/cookies.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/prototype/tooltip.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/w2e/jquery.owlcarousel.min.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/jquery/jquery.printf.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/mana/core.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/jquery/history.adapter.jquery.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/jquery/history.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/jquery/jquery.easing.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/jquery/advListRotator.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/jquery/jquery-ui.min.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/js/jquery/validate/jquery.validate.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/default/vinoseleccion/js/owl.carousel.min.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/default/vinoseleccion/js/modernizr.min.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/default/vinoseleccion/js/selectivizr.min.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/default/vinoseleccion/js/featherlight.min.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/default/vinoseleccion/js/jquery.jcarousel.min.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/default/vinoseleccion/js/custom.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/default/vinoseleccion/js/zoom.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/default/vinoseleccion/js/jquery.ddslick.min.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/default/default/js/jquery.auto-complete.min.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/default/vinoseleccion/js/newssubscribers/script.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/default/vinoseleccion/js/mana_ajax.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/base/default/js/manapro_filterajax.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/base/default/js/manapro_filtercolors.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/base/default/js/manapro_filterexpandcollapse.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/base/default/js/manapro_filtergroup.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/base/default/js/manapro_filterhelp.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/base/default/js/manapro_filterpositioning.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/base/default/js/manapro_filtershowmore.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/base/default/js/price_slider.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/base/default/js/manapro_filterslider.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/base/default/js/manapro_filtersuperslider.js" type="text/javascript"></script>
# <script src="https://www.vinoseleccion.com/skin/frontend/base/default/js/manapro_filtertree.js" type="text/javascript"></script>
# <script data-group="js001" src="https://www.vinoseleccion.com/js/scommerce/require_jquery.js" type="text/javascript"></script>
# <script data-group="js001" src="https://www.vinoseleccion.com/js/scommerce/gtmpromotion.js" type="text/javascript"></script>
# <link href="https://www.vinoseleccion.com/tipos-de-vino/vino-tinto" rel="canonical"/>
# <!--[if lt IE 8]>
# <link rel="stylesheet" type="text/css" href="https://www.vinoseleccion.com/media/css_secure/2779958e53783735bcfc25cfc0a5318d.css" media="all" />
# <![endif]-->
# <script type="text/javascript">
# //<![CDATA[
# Mage.Cookies.path     = '/';
# Mage.Cookies.domain   = '.vinoseleccion.com';
# //]]>
# </script>
# <script type="text/javascript">
# //<![CDATA[
# optionalZipCountries = ["IE","PA","HK","MO"];
# //]]>
# </script>
# <script>
#         window._trx = window._trx || [];
#         window._trx.push([{"event":"setAccount","account":"ndku07","country":"IT"},{"event":"setConfig","config":{"platform":{"name":"Magento","version":"1.7.0.2","integrationVersion":{"0":"3.1.1"}}}}] );
#     </script>
# <script async="true" src="https://static.transactionale.com/trx/v2/trx.js"></script>
# <script type="application/ld+json">[{"@context":"http:\/\/schema.org","@type":"WebSite","url":"https:\/\/www.vinoseleccion.com\/","name":"Vinoseleccion.com","alternateName":"Vinoseleccion"}]</script>
# <script type="application/ld+json">[{"@context":"http:\/\/schema.org","@type":"Organization","url":"https:\/\/www.vinoseleccion.com\/","logo":"https:\/\/www.vinoseleccion.com\/skin\/frontend\/default\/vinoseleccion\/images\/logo.png","sameAs":["https:\/\/twitter.com\/vinoseleccion","https:\/\/www.facebook.com\/vinoseleccion","https:\/\/www.instagram.com\/vinoseleccion\/"]}]</script>
# <!-- Global site tag (gtag.js) - Google Ads: 1062913549 --> <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-1062913549"></script><script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'AW-1062913549'); </script>
# <script type="text/javascript">
#     //<![CDATA[
#     var jsProducts = [{"id":"AGR-DN0890Y","name":"Malpaso 2019","price":14,"category":"Vinos","brand":"Bodegas Canopy","list":"Category - Default Category","position":1},{"id":"AGR-DN0950Y","name":"Infiltrado 2021","price":52.5,"category":"Vinos","brand":"Bodegas Hacienda del Carche","list":"Category - Default Category","position":2},{"id":"AGR-DC0306Y","name":"Legaris Moradillo de Roa 2018","price":31.8,"category":"Vinos","brand":"Bodegas Legaris","list":"Category - Default Category","position":3},{"id":"AGR-DN0949Y","name":"Orben 2019","price":55.2,"category":"Vinos","brand":"Bodegas Orben","list":"Category - Default Category","position":4},{"id":"AGR-DN0915Y","name":"Habla N\u00ba 28 2019","price":74.7,"category":"Vinos","brand":"Bodegas Habla","list":"Category - Default Category","position":5},{"id":"AGR-DC0330Y","name":"Scala Dei Casa de la Procura 2018","price":101.4,"category":"Vinos","brand":"Scala Dei","list":"Category - Default Category","position":6},{"id":"AGR-DV0959Y","name":"Castillo de Monjard\u00edn Garnacha La Cantera 2020","price":20,"category":"Vinos","brand":"Bodegas Castillo de Monjard\u00edn","list":"Category - Default Category","position":7},{"id":"AGR-DV0742Y","name":"Domaine de Montcy Cheverny Rouge Tradition 2020","price":75,"category":"Vinos","brand":"","list":"Category - Default Category","position":8},{"id":"AGR-DV0994Y","name":"Sumoll 2021","price":61.5,"category":"Vinos","brand":"Can R\u00e0fols dels Caus","list":"Category - Default Category","position":9},{"id":"AGR-DN0991","name":"Horcajo 2016","price":79.9,"category":"Vinos","brand":"Bodegas Cepa 21 ","list":"Category - Default Category","position":10},{"id":"AGR-DP0083","name":"Vi\u00f1a Sastre Acos 2008","price":46.8,"category":"Vinos","brand":"Bodegas Hermanos Sastre","list":"Category - Default Category","position":11},{"id":"AGR-DA0843Y","name":"Paloma M\u00ednguez Bobal 2018","price":51,"category":"Vinos","brand":"\u00a1Ea! Manuel Manzaneque Su\u00e1rez En\u00f3logo y Viticultor","list":"Category - Default Category","position":12},{"id":"AGR-DG0303Y","name":"Veramonte Carm\u00e9n\u00e8re 2020","price":50.1,"category":"Vinos","brand":"Bodegas Veramonte","list":"Category - Default Category","position":13},{"id":"AGR-DP0060Y","name":"Duaia 2017","price":67.8,"category":"Vinos","brand":"Mas Martinet Viticultors","list":"Category - Default Category","position":14},{"id":"AGR-24608","name":"Malleolus 2019","price":31.9,"category":"Vinos","brand":"Bodegas Emilio Moro","list":"Category - Default Category","position":15},{"id":"AGR-DA0865","name":"Borgogno Barolo 2018","price":53,"category":"Vinos Internacionales","brand":"","list":"Category - Default Category","position":16},{"id":"AGR-DC0403Y","name":"Raimat Clamor Tinto 2021","price":6,"category":"Vinos","brand":"Raimat","list":"Category - Default Category","position":17},{"id":"AGR-DN0993Y","name":"Valderroa Menc\u00eda 2020","price":55.5,"category":"Vinos","brand":"Bodegas Valdesil","list":"Category - Default Category","position":18},{"id":"AGR-DV0845Y","name":"Gago 2018","price":18.2,"category":"Vinos","brand":"Compa\u00f1\u00eda de Vinos Telmo Rodr\u00edguez","list":"Category - Default Category","position":19},{"id":"AGR-DA0971Y","name":"Jim\u00e9nez-Landi El Corral\u00f3n 2021","price":77.4,"category":"\u00daltimas Botellas - La Feria de Vinoselecci\u00f3n","brand":"Bodegas Jim\u00e9nez - Landi","list":"Category - Default Category","position":20},{"id":"AGR-DO0376Y","name":"Heredad X 2020","price":7.4,"category":"Vinos","brand":"Bodegas Carlos Valero ","list":"Category - Default Category","position":21},{"id":"AGR-DV0883","name":"Domaine Henri Magnien Gevrey-Chambertin Vieilles Vignes 2018","price":61.9,"category":"Vinos Internacionales","brand":"","list":"Category - Default Category","position":22},{"id":"AGR-DP0662Y","name":"Martinet Bru 2020","price":80.7,"category":"Vinos","brand":"Mas Martinet Viticultors","list":"Category - Default Category","position":23},{"id":"AGR-DO0372Y","name": ...
#     Mage.Cookies.set("productlist", "");
#     Mage.Cookies.set("googlecategory","");
#
#     window.dataLayer = window.dataLayer || [];
#     dataLayer.push({
#         'event': 'view_item_list',
#         'ecommerce': {
#             'currencyCode': 'EUR',                       // Local currency is optional.
#             'impressions': [
#                                 {
#                     'name': 'Malpaso 2019',
#                     'id': 'AGR-DN0890Y',
#                     'price': '14',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Infiltrado 2021',
#                     'id': 'AGR-DN0950Y',
#                     'price': '52.5',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Legaris Moradillo de Roa 2018',
#                     'id': 'AGR-DC0306Y',
#                     'price': '31.8',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Orben 2019',
#                     'id': 'AGR-DN0949Y',
#                     'price': '55.2',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Habla Nº 28 2019',
#                     'id': 'AGR-DN0915Y',
#                     'price': '74.7',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Scala Dei Casa de la Procura 2018',
#                     'id': 'AGR-DC0330Y',
#                     'price': '101.4',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Castillo de Monjardín Garnacha La Cantera 2020',
#                     'id': 'AGR-DV0959Y',
#                     'price': '20',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Domaine de Montcy Cheverny Rouge Tradition 2020',
#                     'id': 'AGR-DV0742Y',
#                     'price': '75',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Sumoll 2021',
#                     'id': 'AGR-DV0994Y',
#                     'price': '61.5',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Horcajo 2016',
#                     'id': 'AGR-DN0991',
#                     'price': '79.9',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Viña Sastre Acos 2008',
#                     'id': 'AGR-DP0083',
#                     'price': '46.8',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Paloma Mínguez Bobal 2018',
#                     'id': 'AGR-DA0843Y',
#                     'price': '51',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Veramonte Carménère 2020',
#                     'id': 'AGR-DG0303Y',
#                     'price': '50.1',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Duaia 2017',
#                     'id': 'AGR-DP0060Y',
#                     'price': '67.8',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Malleolus 2019',
#                     'id': 'AGR-24608',
#                     'price': '31.9',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Borgogno Barolo 2018',
#                     'id': 'AGR-DA0865',
#                     'price': '53',
#                     //'brand': '',
#                     'category': 'Vinos Internacionales',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Raimat Clamor Tinto 2021',
#                     'id': 'AGR-DC0403Y',
#                     'price': '6',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Valderroa Mencía 2020',
#                     'id': 'AGR-DN0993Y',
#                     'price': '55.5',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Gago 2018',
#                     'id': 'AGR-DV0845Y',
#                     'price': '18.2',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Jiménez-Landi El Corralón 2021',
#                     'id': 'AGR-DA0971Y',
#                     'price': '77.4',
#                     //'brand': '',
#                     'category': 'Últimas Botellas - La Feria de Vinoselección',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Heredad X 2020',
#                     'id': 'AGR-DO0376Y',
#                     'price': '7.4',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Domaine Henri Magnien Gevrey-Chambertin Vieilles Vignes 2018',
#                     'id': 'AGR-DV0883',
#                     'price': '61.9',
#                     //'brand': '',
#                     'category': 'Vinos Internacionales',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Martinet Bru 2020',
#                     'id': 'AGR-DP0662Y',
#                     'price': '80.7',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Bela 2020',
#                     'id': 'AGR-DO0372Y',
#                     'price': '65.4',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Gg 2019',
#                     'id': 'AGR-DP0117',
#                     'price': '50.4',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'G2 Garnacha Centenaria 2020',
#                     'id': 'AGR-DN0963Y',
#                     'price': '12',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Malabrigo 2019',
#                     'id': 'AGR-DN1001',
#                     'price': '32.25',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Casa Castillo 2021',
#                     'id': 'AGR-DA0969Y',
#                     'price': '6.75',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Prados Colección Garnacha 2020',
#                     'id': 'AGR-DN0927Y',
#                     'price': '12',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Lafou de Batea 2016',
#                     'id': 'AGR-DN0819',
#                     'price': '41.5',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Venus de La Figuera 2017',
#                     'id': 'AGR-DP0071',
#                     'price': '55.8',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Cune Ecológico 2020',
#                     'id': 'AGR-DO0453Y',
#                     'price': '40.2',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Angelitos Negros 2020',
#                     'id': 'DA0790Y',
#                     'price': '59.4',
#                     //'brand': '',
#                     'category': 'New',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Atlántida 2018',
#                     'id': 'AGR-DO0426Y',
#                     'price': '77.7',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Usted 2017',
#                     'id': 'AGR-DP0118',
#                     'price': '176',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Finca Teira 2021',
#                     'id': 'AGR-DO0422Y',
#                     'price': '12',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Sensal 2021',
#                     'id': 'AGR-DV0999Y',
#                     'price': '65.7',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Mouton Cadet Réserve Saint-Émilion 2018',
#                     'id': 'AGR-DT0497',
#                     'price': '25',
#                     //'brand': '',
#                     'category': 'Vinos Internacionales',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Secastilla 2017',
#                     'id': 'AGR-DN0891Y',
#                     'price': '75',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Siete Vidas Parcelas Singulares 2021',
#                     'id': 'AGR-DO0474Y',
#                     'price': '15.2',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Tr3smano Vendimia 2019',
#                     'id': 'AGR-DN1016',
#                     'price': '34.9',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Domaine Henri Magnien Gevrey-Chambertin Vieilles Vignes 2019',
#                     'id': 'AGR-DV0826',
#                     'price': '61.9',
#                     //'brand': '',
#                     'category': 'Vinos Internacionales',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Las Mulas Cabernet Sauvignon 2021',
#                     'id': 'AGR-DT0572Y',
#                     'price': '9.2',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Pujanza Hado 2018',
#                     'id': 'AGR-DP0088Y',
#                     'price': '12.6',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Proventus 2019',
#                     'id': 'DN0939Y',
#                     'price': '59.7',
#                     //'brand': '',
#                     'category': 'New',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Raimat El Molí Cabernet Sauvignon-Syrah 2018',
#                     'id': 'AGR-DC0313Y',
#                     'price': '10.5',
#                     //'brand': '',
#                     'category': 'Rioja',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'Pago de Valtarreña 2018',
#                     'id': 'AGR-DN0873',
#                     'price': '47.9',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                             },
#                                 {
#                     'name': 'A Villeira Mencía 2019',
#                     'id': 'AGR-DO0378',
#                     'price': '28',
#                     //'brand': '',
#                     'category': 'Vinos',
#                     //'list': '',
#                     //'position': ''
#                                     }]
#                         }
#     });
#     //]]>
# </script>
# <script type="text/javascript">
#     //<![CDATA[
#     gtmPro(document).ready(function() {
#         var jsProductUrls = ["https:\/\/www.vinoseleccion.com\/malpaso-2019","https:\/\/www.vinoseleccion.com\/infiltrado-2021","https:\/\/www.vinoseleccion.com\/legaris-moradillo-roa-2018","https:\/\/www.vinoseleccion.com\/orben-2019","https:\/\/www.vinoseleccion.com\/habla-n-28-2019","https:\/\/www.vinoseleccion.com\/scala-dei-casa-procura-2018","https:\/\/www.vinoseleccion.com\/castillo-monjardin-garnacha-cantera-2020","https:\/\/www.vinoseleccion.com\/domaine-montcy-cheverny-rouge-tradition-2020","https:\/\/www.vinoseleccion.com\/sumoll-2021","https:\/\/www.vinoseleccion.com\/horcajo-2016","https:\/\/www.vinoseleccion.com\/vina-sastre-acos-2008","https:\/\/www.vinoseleccion.com\/paloma-minguez-bobal-2018","https:\/\/www.vinoseleccion.com\/veramonte-carmenere-2020","https:\/\/www.vinoseleccion.com\/duaia-2017","https:\/\/www.vinoseleccion.com\/malleolus-2019","https:\/\/www.vinoseleccion.com\/borgogno-barolo-2018","https:\/\/www.vinoseleccion.com\/raimat-clamor-2021","https:\/\/www.vinoseleccion.com\/valderroa-mencia-2020","https:\/\/www.vinoseleccion.com\/gago-2018","https:\/\/www.vinoseleccion.com\/jimenez-landi-corralon-2021","https:\/\/www.vinoseleccion.com\/heredad-x-2020","https:\/\/www.vinoseleccion.com\/domaine-henri-magnien-gevrey-chambertin-vieilles-vignes-2018","https:\/\/www.vinoseleccion.com\/martinet-bru-2020","https:\/\/www.vinoseleccion.com\/bela-2020","https:\/\/www.vinoseleccion.com\/gg-2019","https:\/\/www.vinoseleccion.com\/g2-garnacha-centenaria-2020","https:\/\/www.vinoseleccion.com\/malabrigo-2019","https:\/\/www.vinoseleccion.com\/casa-castillo-2021","https:\/\/www.vinoseleccion.com\/prados-coleccion-garnacha-2020","https:\/\/www.vinoseleccion.com\/lafou-batea-2016","https:\/\/www.vinoseleccion.com\/venus-figuera-2017","https:\/\/www.vinoseleccion.com\/cune-ecologico-2020","https:\/\/www.vinoseleccion.com\/angelitos-negros-2020-da0790y","https:\/\/www.vinoseleccion.com\/atlantida-2018","https:\/\/www.vinoseleccion.com\/usted-2017","https:\/\/www.vinoseleccion.com\/finca-teira-2021","https:\/\/www.vinoseleccion.com\/sensal-2021","https:\/\/www.vinoseleccion.com\/mouton-cadet-reserve-saint-emilion-2018","https:\/\/www.vinoseleccion.com\/secastilla-2017","https:\/\/www.vinoseleccion.com\/siete-vidas-roble-2021","https:\/\/www.vinoseleccion.com\/tr3smano-vendimia-2019","https:\/\/www.vinoseleccion.com\/domaine-henri-magnien-gevrey-chambertin-vieilles-vignes-2019","https:\/\/www.vinoseleccion.com\/mulas-cabernet-sauvignon-2021","https:\/\/www.vinoseleccion.com\/pujanza-hado-2018","https:\/\/www.vinoseleccion.com\/proventus-2019-dn0939y","https:\/\/www.vinoseleccion.com\/raimat-moli-cabernet-sauvignon-syrah-2018","https:\/\/www.vinoseleccion.com\/pago-valtarrena-2018","https:\/\/www.vinoseleccion.com\/villeira-mencia-2019"];
#         var jsClickLabel = 'Category - Default Category';
#         gtmPro('a').on('click', function(e){
#             var product;
#             var href = gtmPro(this).attr('href');
#             var index = jsProductUrls.indexOf(href);
#
#             if (index != -1 ){//&& window.ga && ga.loaded){
#                 e.preventDefault(e);
#                 product = jsProducts[index];
#                 Mage.Cookies.set('productlist', product.list);
#                 Mage.Cookies.set('googlecategory', product.category);
#                 dataLayer.push({
#                     'event': 'productClick',
#                     'ecommerce': {
#                         'click': {
#                             'actionField': {'list': 'Category - Default Category'},      // Optional list property.
#                             'products': [{
#                                 'name': product.name,                      // Name or ID is required.
#                                 'id': product.id,
#                                 'price': product.price,
#                                 'brand': product.brand,
#                                 'category': product.category,
#                                 'position': product.position
#                             }]
#                         }
#                     },
#                     'eventCallback': function() {
#                         if (!(e.ctrlKey || e.which==2)){
#                             document.location = href;
#                         }
#                     }
#                 });
#             }else{
#                 document.location = href;
#             }
#         });
#     });
#     //]]>
# </script><script>
# //<![CDATA[
#
# function manipulationOfCart(product, type, list) {
# 	if (list == undefined || (list == '' && product.category != '')){
# 		list='Category - '+ product.category
# 	}
#
#     if (type == 'add'){
# 	    dataLayer.push({
# 		  'event': 'addToCart',
# 		  'ecommerce': {
# 			'currencyCode': 'EUR',
# 			'add': {                                // 'add' actionFieldObject measures.
# 			  'actionField': {'list': list},
# 			  'products': [{                        //  adding a product to a shopping cart.
# 				'name': product.name,
# 				'id': product.id,
# 				'price': product.price,
# 				'brand': product.brand,
# 				'category': product.category,
# 				'quantity': product.qty,
# 				'list': list
# 			   }]
# 			}
# 		  }
# 		});
#     }
#     else if (type == 'remove'){
# 	    dataLayer.push({
# 		  'event': 'removeFromCart',
# 		  'ecommerce': {
# 			'currencyCode': 'EUR',
# 			'remove': {                             // 'remove' actionFieldObject measures.
# 			  'actionField': {'list': list},
# 			  'products': [{                        //  adding a product to a shopping cart.
# 				'name': product.name,
# 				'id': product.id,
# 				'price': product.price,
# 				'brand': product.brand,
# 				'category': product.category,
# 				'quantity': product.qty,
# 				'list': list
# 			   }]
# 			}
# 		  }
# 		});
#     }
# }
#
# gtmPro(document).ready(function() {
#     gtmPro('.header-container a').first().on('click', function (e) {
#         var href = gtmPro(this).attr('href');
#         var title = gtmPro(this).attr('title');
#         dataLayer.push({
#             'event': 'promotionClick',
#             'ecommerce': {
#                 'name': title,
#                 'href': href
#             },
#             'eventCallback': function () {
#                 if (!(e.ctrlKey || e.which == 2)) {
#                     document.location = href;
#                 }
#             }
#         });
#     });
# });
# //]]>
# </script>
# <!-- Scommerce Mage Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KJ6D2S');</script>
# <!-- End Scommerce Mage Google Tag Manager -->
# <script type="text/javascript">//<![CDATA[
#         var Translator = new Translate({"Please select an option.":"Por favor, seleccione una opci\u00f3n.","This is a required field.":"Campo requerido.","Please enter a valid number in this field.":"Por favor, escriba un n\u00famero v\u00e1lido en este campo.","Please use numbers only in this field. Please avoid spaces or other characters such as dots or commas.":"Introduzca \u00fanicamente n\u00fameros positivos en este campo.","Please use letters only (a-z or A-Z) in this field.":"Por favor, utilice s\u00f3lo letras (a-z o A-Z) en este campo.","Please use only letters (a-z), numbers (0-9) or underscore(_) in this field, first character should be a letter.":"Por favor, use s\u00f3lo letras (a-z), n\u00fameros (0-9) o guiones bajos(_) en este campo. El primer car\u00e1cter debe ser una letra.","Please enter a valid phone number. For example (123) 456-7890 or 123-456-7890.":"Por favor, escriba un n\u00famero de tel\u00e9fono v\u00e1lido.","Please enter a valid date.":"Por favor, escriba una fecha v\u00e1lida.","Please enter a valid email address. For example johndoe@domain.com.":"Por favor, escriba una direcci\u00f3n de correo v\u00e1lida. Por ejemplo perez@dominio.com","Please enter 6 or more characters. Leading or trailing spaces will be ignored.":"Por favor, escriba 6 o m\u00e1s caracteres. Los espacios al principio y al final ser\u00e1n ignorados.","Please enter 7 or more characters. Password should contain both numeric and alphabetic characters.":"Por favor introduzca al menos 7 caracteres. La contrase\u00f1a debe contener n\u00fameros y letras.","Please make sure your passwords match.":"Aseg\u00farese de que sus contrase\u00f1as coinciden.","Please enter a valid URL. For example http:\/\/www.example.com or www.example.com":"Por favor, escriba una URL v\u00e1lida. Por ejemplo http:\/\/www.ejemplo.com o www.ejemplo.com","Please enter a valid social security number. For example 123-45-6789.":"Por favor, escriba un n\u00famero v\u00e1lido de seguridad social.","Please enter a valid zip code. For example 90602 or 90602-1234.":"Por favor, escriba un c\u00f3digo postal v\u00e1lido.","Please enter a valid zip code.":"Por favor, escriba un c\u00f3digo postal v\u00e1lido.","Please use this date format: dd\/mm\/yyyy. For example 17\/03\/2006 for the 17th of March, 2006.":"Por favor, use este formato de fecha: dd\/mm\/aaaa. Por ejemplo, 17\/03\/2006 para 17 de marzo de 2006.","Please enter a valid $ amount. For example $100.00.":"Por favor, escriba un importe v\u00e1lido.","Please select one of the above options.":"Por favor, seleccione una de las opciones arriba.","Please select one of the options.":"Por favor, seleccione una de las opciones.","Please select State\/Province.":"Por favor, seleccione Estado\/Provincia","Please enter a number greater than 0 in this field.":"Por favor, escriba un n\u00famero mayor que 0 en este campo.","Please enter a valid credit card number.":"Por favor, escriba un n\u00famero de tarjeta de cr\u00e9dito v\u00e1lido.","Credit card number does not match credit card type.":"El n\u00famero de cuenta introducido no concuerda con el tipo de tarjeta.","Card type does not match credit card number.":"El tipo de tarjeta no concuerda con el n\u00famero de cuenta introducido.","Incorrect credit card expiration date.":"Fecha de caducidad incorrecta.","Text length does not satisfy specified text range.":"El campo inclumple el n\u00famero de caracteres m\u00ednimo o m\u00e1ximo","Please wait, loading...":"Por favor, espere. Cargando...","This date is a required value.":"Campo requerido","Please enter a valid day (1-%d).":"Por favor, introduce el d\u00eda correcto (1-%d).","Please enter a valid month (1-12).":"Por favor, introduzca un mes v\u00e1lido (1-12)","Please enter a valid year (1900-%d).":"Por favor, introduce un a\u00f1o correcto (1900-%d).","Please enter a valid full date":"Por favor, ingrese una fecha v\u00e1lida.","Please enter a valid date between %s and %s":"Por favor, introduce una fecha entre %s y % ...
#         //]]></script><meta content="2wcmbNHcO5akcM2NHkSJ7TFy7hf3t8uyZag1YZRRgmQ" name="google-site-verification"/>
# <meta content="721BAB76C742C3D80BF3667E59CD6D7E" name="msvalidate.01"/>
# <!-- Hotjar Tracking Code for https://www.vinoseleccion.com -->
# <script>
#     (function(h,o,t,j,a,r){
#         h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#         h._hjSettings={hjid:2957631,hjsv:6};
#         a=o.getElementsByTagName('head')[0];
#         r=o.createElement('script');r.async=1;
#         r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# </script>
# <style type="text/css">
# #obsequiocrm-progress-opcheckout { width: 45%; float: left; margin: 20px 0 0 5%; max-width: 270px; display:none }
# </style>
# <script async="" data-cbid="c7744a83-f0ba-4331-826a-0c03bd6c154f" id="Cookiebot" src="https://consent.cookiebot.com/uc.js" type="text/javascript"></script>
# <!-- Chat Inconcert -->
# <script type="text/javascript">
#   (function() {
#     var proto  = document.location.protocol || 'http:';
#     var node   = document.createElement('script');
#     node.type  = 'text/javascript';
#     node.async = true;
#     node.src   = proto +  '//webchat-cls18-itx-mad.i6.inconcertcc.com/v3/click_to_chat?token=37317EBB43E60B14CD7F61E7AEF6DEF0';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(node, s);
#   })();
# </script>
# <!-- Chat Inconcert -->
# <link href="https://www.vinoseleccion.com" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.vinoseleccion.co.uk" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.vinoseleccion.de" hreflang="de-DE" rel="alternate"/>
# <link href="https://www.vinoseleccion.nl" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.vinoseleccion.fr" hreflang="fr-FR" rel="alternate"/>
# <script>
# window.addEventListener('CookiebotOnDialogDisplay', function(e){
#     var btnText = ['ACEPTAR TODAS LAS COOKIES', 'GUARDAR'],
#         dialogExpanded = false,
#         ref = document.getElementById('CybotCookiebotDialogBodyButtonDetails'),
#         btn = document.createElement('a');
#
#     function selection() {
#         var p = document.getElementById('CybotCookiebotDialogBodyLevelButtonPreferences').checked,
#             s = document.getElementById('CybotCookiebotDialogBodyLevelButtonStatistics').checked,
#             m = document.getElementById('CybotCookiebotDialogBodyLevelButtonMarketing').checked;
#         Cookiebot.submitCustomConsent(p, s, m),
#         Cookiebot.hide();
#     }
#     function acceptAll() {
#         document.getElementById('CybotCookiebotDialogBodyLevelButtonPreferences').checked = true;
#         document.getElementById('CybotCookiebotDialogBodyLevelButtonStatistics').checked = true;
#         document.getElementById('CybotCookiebotDialogBodyLevelButtonMarketing').checked = true;
#         Cookiebot.submitConsent();
#     }
#     btn.id = 'CookiebotDialogButton';
#     btn.href = 'javascript: void(0);';
#     btn.setAttribute = ('class', 'CybotCookiebotDialogBodyButton');
#     btn.style = 'padding-left: 15px; padding-right: 15px;background-color: #188600;border: 1px solid #188600;';
#     btn.innerText = btnText[0];
#     btn.addEventListener('click', acceptAll);
#     document.getElementById('CybotCookiebotDialogBodyButtonAccept').style.display = 'none';
#     ref.parentNode.insertBefore(btn, ref);
#     ref.addEventListener('click', function(e){
#         var b = document.getElementById('CookiebotDialogButton');
#         dialogExpanded = dialogExpanded ? !1 : !0;
#         btn.innerText = dialogExpanded ? btnText[1] : btnText[0];
#         if (dialogExpanded) {
#             b.removeEventListener('click', acceptAll);
#             b.addEventListener('click', selection);
#         } else {
#             b.removeEventListener('click', selection);
#             b.addEventListener('click', acceptAll);
#         }
#     }, false);
# }, false);
# </script>
# </head>
# <body class="vinoseleccion-winetype-view special-category-view entities-winetype-entities-winetype21">
# <!-- Scommerce Mage Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-KJ6D2S" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- Scommerce Mage End Google Tag Manager -->
# <script>
#     var storageData = JSON.parse(localStorage.getItem('utm_source'));
#     if(storageData != null) {
# ...
#
#                         });
#                     }
#                 });
#             </script>
# <script>
#                 var storageData = JSON.parse(localStorage.getItem('utm_source'));
#                 var origenValue = 'POPUP';
#                 if(storageData != null) {
#                     origenValue = storageData.source;
#                 }
#                 document.getElementById('origen').value = origenValue;
#             </script>
# </div>
# <script type="text/javascript">
# //<![CDATA[
# (function($) {
# 	$.options({"#m-ajax":{"enabled":false,"selectors":{"filter":[".mb-category-products",".mb-mana-catalog-leftnav",".mb-mana-catalog-rightnav"]},"debug":false,"method":"2","progress":{"filter":true},"overlay":{"filter":true}}});
# })(jQuery);
# //]]>
# </script>
# <div id="m-wait" style="display:none;">
# <p class="loader" id="loading_mask_loader"><img alt="Cargando..." src="https://www.vinoseleccion.com/skin/frontend/base/default/images/mana_core/m-wait.gif"><br>Por favor espere...</br></img></p>
# </div>
# <div class="m-popup" id="m-popup" style="display:none;">
# </div>
# <script>
#     var redirigido = {
#
#         boxClose: function()
#         {
#             jQuery('#esns_background_layer2').fadeOut();
#         },
#
#         boxOpen: function()
#         {
#             jQuery('#esns_background_layer2').fadeIn();
#         }
#
#     };
#
#     jQuery(document).ready(function() {
#         jQuery('#esns_box_layer2').css('margin-top', ((jQuery(window).height() - jQuery('#esns_box_layer').height()) / 2) + 'px');
#
#         redirigido.boxOpen();
#
#         setTimeout(function(){
#             redirigido.boxClose();
#         }, 10000);
#
#         jQuery('#esns_box_close2').click(function(){
#             redirigido.boxClose();
#         });
#     });
# </script>
# <script type="text/javascript">
# //<![CDATA[
# (function($) {
# 	$.options({"#m-ajax":{"enabled":false,"selectors":{"filter":[".mb-category-products",".mb-mana-catalog-leftnav",".mb-mana-catalog-rightnav"]},"debug":false,"method":"2","progress":{"filter":true},"overlay":{"filter":true}}});
# })(jQuery);
# //]]>
# </script>
# <div id="m-wait" style="display:none;">
# <p class="loader" id="loading_mask_loader"><img alt="Cargando..." src="https://www.vinoseleccion.com/skin/frontend/base/default/images/mana_core/m-wait.gif"><br>Por favor espere...</br></img></p>
# </div>
# <div class="m-popup" id="m-popup" style="display:none;">
# </div>
# </div>
# </div>
# <script id="search-code" type="text/x-mustache-template">
#     {{#results}}<div class="pure-g" style="margin-top:20px;padding-right: 10px;"> <div class="pure-u-1" style="min-height: 50px;"> <span class="product-title"><a href="{{link}}">{{title}}</a></span> </div> <div class="pure-u-1" style="min-height:180px"> <a href="{{link}}" class="img-search-div"> <img class="img-search" src="{{#remove-protocol}}{{image_link}}{{/remove-protocol}}" alt="{{title}}"> </a> </div> {{#gourmet}} {{#el_0_price}} <div class="pure-u-1"> <div class="pure-g"> <div class="pure-u-1-3 bottlequantity"> <img width="12px" src="/skin/frontend/default/vinoseleccion/images/bg-food.png"> </div>{{#el_0_offer}} <div class="pure-u-1-3 price-search"> <span style="text-decoration:line-through;">{{el_0_reference}}</span> {{el_0_offer}}{{el_0_price}} € </div>{{/el_0_offer}}{{^el_0_offer}} <div class="pure-u-1-3 price-search"> {{el_0_price}} € </div>{{/el_0_offer}} <div class="pure-u-1-3 buy-button" data-addtocart="{{el_0_id}}" data-qty="1"> <button type="button" title="Comprar" class="button btn-cart"> <span>Comprar</span></button> </div> </div> </div> {{/el_0_price}} {{#el_1_price}} <div class="pure-u-1"> <div class="pure-g"> <div class="pure-u-1-3 bottlequantity"> <img width="12px" src="/skin/frontend/default/vinoseleccion/images/bg-food.png"> </div> <div class="pure-u-1-3 price-search"> <span style="text-decoration:line-through;">{{el_1_reference}}</span> {{el_1_price}} € </div> <div class="pure-u-1-3 buy-button" data-addtocart="{{el_1_id}}" data-qty="1"> <button type="button" title="Comprar" class="button btn-cart"> <span>Comprar</span></button> </div> </div> </div> {{/el_1_price}} {{#el_2_price}} <div class="pure-u-1"> <div class="pure-g"> <div class="pure-u-1-3 bottlequantity"> <img width="12px" src="/skin/frontend/default/vinoseleccion/images/bg-food.png"> </div> <div class="pure-u-1-3 price-search"> <span style="text-decoration:line-through;">{{el_2_reference}}</span> {{el_2_price}} € </div> <div class="pure-u-1-3 buy-button" data-addtocart="{{el_2_id}}" data-qty="1"> <button type="button" title="Comprar" class="button btn-cart"> <span>Comprar</span></button> </div> </div> </div> {{/el_2_price}} {{/gourmet}} {{^gourmet}} {{#el_0_price}} <div class="pure-u-1"> <div class="pure-g"> <div class="pure-u-1-3 bottlequantity"> {{el_0_num}} <img width="7px" src="/skin/frontend/default/vinoseleccion/images/bg-botella-list.png"> </div> <div class="pure-u-1-3 price-search" style="position:relative"> {{#el_0_offer}}<span style="position:absolute;top: -10px;left: 22px;font-size: 13px;text-decoration: line-through;color: #810d18;">{{el_0_reference}} €</span><span style="position:absolute;top: 10px;left: 19px;">{{el_0_price}} €</span>{{/el_0_offer}} {{^el_0_offer}}{{el_0_price}} € {{/el_0_offer}} </div> <div class="pure-u-1-3 buy-button" data-addtocart="{{el_0_id}}" data-qty="1"> <button type="button" title="Comprar" class="button btn-cart"> <span>Comprar</span></button> </div> </div> </div> {{#el_0_multiplicador_num}} <div class="pure-u-1"> <div class="pure-g"> <div class="pure-u-1-3 bottlequantity"> {{el_0_multiplicador_num}} <img width="7px" src="/skin/frontend/default/vinoseleccion/images/bg-botella-list.png"> </div> <div class="pure-u-1-3 price-search"> {{el_0_multiplicador_price}} € </div> <div class="pure-u-1-3 buy-button" data-addtocart="{{el_0_id}}" data-qty="{{el_0_multiplicador_num}}"> <button type="button" title="Comprar" class="button btn-cart"> <span>Comprar</span></button> </div> </div> </div> {{/el_0_multiplicador_num}} {{/el_0_price}} {{#el_1_price}} <div class="pure-u-1"> <div class="pure-g"> <div class="pure-u-1-3 bottlequantity"> {{el_1_num}} <img width="7px" src="/skin/frontend/default/vinoseleccion/images/bg-botella-list.png"> </div> <div class="pure-u-1-3 price-search" style="position:relative"> {{#el_1_offer}}<span style="position:absolute;top: -10px;left: 22px;font-size: 13px;text-decoration: line-through;color: #810d18;">{{el_1_reference}} €</span><span style="position:absolute;top: 10px;left: 19px;">{{el_ ...
# </script>
# <script>
#     if (!document.getElementById("searchResultsDoofinder")) {
#
#         var doofinder_script ='//cdn.doofinder.com/media/js/doofinder-classic.7.latest.min.js';
#         (function(d,t){var f=d.createElement(t),s=d.getElementsByTagName(t)[0];f.async=1;
#             f.src=('https:'==location.protocol?'https:':'http:')+doofinder_script;
#             f.setAttribute('charset','utf-8');
#             s.parentNode.insertBefore(f,s)}(document,'script'));
#
#         let embeddedPath = "/buscador"
#
#         var dfClassicLayers = [{
#             "mobile": {
#                 "display": {
#                     "results": {
#                         template: document.getElementById('search-code').innerHTML
#                     }
#                 }
#             },
#             "queryInput": "#search",
#             "hashid": "47e5efc24c95fa14d48186d8c92461a6",
#             "urlHash": true,
#             "zone": "eu1",
#             "searchParams": {
#                 "rpp":12,
#             },
#             "callbacks": {
#                 loaded: function(instance) {
#                     instance.layer.layer.on('click', '[data-addtocart]', function(e){
#                         var productId = parseInt(this.getAttribute('data-addtocart'), 10);
#                         var qty = parseInt(this.getAttribute('data-qty'), 10);
#                         window.location.href="https://www.vinoseleccion.com/checkout/cart/add?product="+productId+"&qty="+qty;
#                     });
#
#                     instance.layer.queryInput.on("keydown", (e) => {
#                         if (e.keyCode == 13 && document.getElementById('search').value.length) {
#                             document.location = embeddedPath + "#/embedded/" +
#                                 instance.layer.controller.serializeStatus();
#                             e.preventDefault();
#                         }
#                     });
#
#                 }
#             },
#             "display": {
#                 "captureLength": 4,
#                 "wait": 72,
#                 "facets": {
#                     startCollapsed: true
#                 },
#                 "lang": "es",
#                 "results": {
#                     initialLayout: 'grid',
#                     template: document.getElementById('search-code').innerHTML
#                 }
#             },
#             "searchParams": {
#                 "rpp":12
#             },
#             "zone": "eu1",
#         }];
#         jQuery('#sendSearch').click(function(){
#             let embeddedPath = "/buscador";
#             if(document.getElementById('search').value.length ) {
#             document.location = embeddedPath + "#/embedded/query=" + document.getElementById('search').value + "&query_name=phonetic_text";
#             }
#         });
#
#     } else {
#         document.getElementById("search_mini_form").onsubmit = function() {
#             return false;
#         };
#         var doofinder_script ='//cdn.doofinder.com/media/js/doofinder-embedded.7.latest.min.js';
#         (function(d,t){var f=d.createElement(t),s=d.getElementsByTagName(t)[0];f.async=1;
#             f.src=('https:'==location.protocol?'https:':'http:')+doofinder_script;
#             f.setAttribute('charset','utf-8');
#             s.parentNode.insertBefore(f,s)}(document,'script'));
#
#         var dfEmbeddedLayers = [{
#
#             "mobile": {
#                 "display": {
#                     "results": {
#                         template: document.getElementById('search-code').innerHTML
#                     }
#                 }
#             },
#             "queryInput": "#search",
#             "hashid": "47e5efc24c95fa14d48186d8c92461a6",
#             "urlHash": true,
#             "zone": "eu1",
#             "searchParams": {
#                 "rpp":12,
#             },
#             "callbacks": {
#                 loaded: function(instance) {
#                     instance.layer.layer.on('click', '[data-addtocart]', function(e){
#                         var productId = parseInt(this.getAttribute('data-addtocart'), 10);
#                         var qty = parseInt(this.getAttribute('data-qty'), 10);
#                         window.location.href="https://www.vinoseleccion.com/checkout/cart/add?product="+productId+"&qty="+qty;
#                     });
#                 }
#             },
#             "display": {
#                 "captureLength": 4,
#                 "wait": 72,
#                 "facets": {
#                     startCollapsed: true
#                 },
#                 "lang": "es",
#                 insertionPoint: "#searchResultsDoofinder",
#                 "results": {
#                     initialLayout: 'grid',
#                     template: document.getElementById('search-code').innerHTML
#                 }
#
#             }
#         }];
#     }
#     jQuery('#search').focus(function(){
#         jQuery(this).data('placeholder',jQuery(this).attr('placeholder'))
#             .attr('placeholder','');
#     }).blur(function(){
#         jQuery(this).attr('placeholder',jQuery(this).data('placeholder'));
#     });
# </script>
# <style>
#     .img-search{
#         display: block;
#         max-height: 100%;
#         max-width: 100%;
#         width: auto;
#     }
#     .img-search-div {
#         -webkit-box-flex: 0;
#         -webkit-flex: 0 0 auto;
#         -ms-flex: 0 0 auto;
#         flex: 0 0 auto;
#         height: 180px;
#         padding: 0;
#         overflow: hidden;
#         display: -webkit-box;
#         display: -webkit-flex;
#         display: -ms-flexbox;
#         display: flex;
#         -webkit-box-pack: center;
#         -webkit-justify-content: center;
#         -ms-flex-pack: center;
#         justify-content: center;
#         -webkit-box-align: center;
#         -webkit-align-items: center;
#         -ms-flex-align: center;
#         align-items: center;
#     }
#
#     .df-results {
#         grid-template-columns: repeat(auto-fill,minmax(280px,1fr)) !important;
#     }
#
#     .price-search{
#         font-weight: 700;
#         font-size: 18px;
#         color: #333;
#         line-height: 45px;
#         padding-right: 10px;
#     }
#
#     .buy-button {
#         cursor: pointer;
#         float: left;
#         height: 40px;
#         background: url(https://www.vinoseleccion.com/skin/frontend/default/vinoseleccion/images/cart.png) no-repeat center center;
#         background-size: 30px;
#         overflow: hidden;
#         border: 2px solid #868686;
#         text-indent: -999999px;
#         font-size: 0;
#         border-radius: 2px;
#     }
#     .bottlequantity {
#         padding-top: 10px;
#         font-weight: 600;
#         font-size: 16px;
#     }
#
#     .df-results .pure-g .pure-u-1 .product-title{
#         min-height: 40px;
#         margin: 0 0 7px;
#         font-weight: normal;
#         font-size: 16px;
#         color: #000;
#         text-align: center;
#     }
#
#     .buy-button:hover {
#         background: url(https://www.vinoseleccion.com/skin/frontend/default/vinoseleccion/images/cart-white.png) no-repeat center center;
#         background-size: 30px;
#         background-color: #bc1724;
#         border: 2px solid #bc1724;
#     }
#
#     .std ul {
#         list-style: none;
#         padding-left: 1.5em;
#     }
#     .df-slider .noUi-base, .df-slider .noUi-connects {
#         z-index: 0 !important;
#     }
#     .df-panel__content {
#         padding: 0px !important;
#     }
#
#     .df-aside .df-panel__title {
#         color: #211915 !important;
#         padding: 8px !important;
#         font-weight: 600 !important;
#         font-size: 16px !important;
#         cursor: pointer !important;
#         border-top: 1px solid #808080 !important;
#         text-align: left !important;
#     }
#
#     .df-panel--collapse[data-collapse=true] .df-panel__title {
#         background-image: url(https://www.vinoseleccion.com/media/arrow-black.png) !important;
#     }
#     .df-panel--collapse[data-collapse=false] .df-panel__title {
#         background-image: url(https://www.vinoseleccion.com/media/arrow-black-up.png) !important;
#     }
#     .df-classic .df-branding {
#         display: none !important;
#     }
#     .df-term__value {
#         text-align: left !important;
#     }
#     .df-mobile[data-layout=grid][data-browser-support~=cssgrid] .df-mobile__content {
#         -ms-grid-columns: (100%)[1] !important;
#         grid-template-columns: repeat(1,100%) !important;
#     }
#     .df-mobile .df-mobile__content {
#         background-color: #fff !important;
#     }
#
#     @media (max-width: 925px) {
#         #opc-review #checkout-review-table-wrapper {
#             width: 100% !important;
#         }
#     }
#
#
#     .df-term {
#         padding: 0px 8px !important;
#         background: transparent url(https://www.vinoseleccion.com/skin/frontend/base/default/images/manapro_filtercheckboxes/checkbox_unchecked.png) 0 2px no-repeat;
#     }
#     span.df-term__value {
#         font: 14px/1.5 'Open Sans', Arial, Helvetica, sans-serif !important;
#         text-rendering: optimizeLegibility !important;
#         padding-left: 13px !important;
#     }
#     .df-term[data-selected] {
#         background: transparent url(https://www.vinoseleccion.com/skin/frontend/base/default/images/manapro_filtercheckboxes/checkbox_checked.png) 0 2px no-repeat !important;
#     }
#
#     .df-classic .df-term[data-selected] {
#         border-color: transparent !important;
#         color: black !important;
#     }
#
#     .df-mobile .df-term{
#         height: auto !important;
#     }
#
#     .df-mobile .df-term[data-selected], .df-mobile .df-term[data-selected] .df-term__count, .df-mobile .df-term[data-selected]:hover {
#         color: #000 !important;
#     }
# </style>
# <script async="" city="dublin" defer="" origin-key="tjo_ylGN7eSbdXYorsqnfLakn8NTQKTEPsXWtnpY" src="https://libs.threatjammer.com/js/tj.js" track="true"></script></body>
# </html>

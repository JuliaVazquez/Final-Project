# %% [markdown]
# ## Import libraries and Dataframe

# %%
import pandas as pd

# %%
df = pd.read_csv('scraping_style.csv')
df.shape
# Out:
# (35910, 11)

# %%
df
# Out:
#          wine_id              varietal_name   style_id       body  acidity_1  \
# 0        1420799  Tinto de Ribera del Duero        180          5          3
# 1        1199830  Tinto de Ribera del Duero        180          5          3
# 2        1494622  Tinto de Ribera del Duero        180          5          3
# 3        1229417  Tinto de Ribera del Duero        180          5          3
# 4       87412043  Tinto de Ribera del Duero        180          5          3
# ...          ...                        ...        ...        ...        ...
# 35905  164784307                  164784307  164784307  164784307  164784307
# 35906   14979215                   14979215   14979215   14979215   14979215
# 35907  169911041                  169911041  169911041  169911041  169911041
# 35908   14979215                   14979215   14979215   14979215   14979215
# 35909  169911041                  169911041  169911041  169911041  169911041
#
#       acidity_description     acidity_2    fizziness     intensity  \
# 0                    Alta  3.700298e+00          NaN  3.837711e+00
# 1                    Alta  3.700298e+00          NaN  3.837711e+00
# 2                    Alta  3.700298e+00          NaN  3.837711e+00
# 3                    Alta  3.700298e+00          NaN  3.837711e+00
# 4                    Alta  3.673210e+00          NaN  3.852942e+00
# ...                   ...           ...          ...           ...
# 35905           164784307  1.647843e+08  164784307.0  1.647843e+08
# 35906            14979215  1.497922e+07   14979215.0  1.497922e+07
# 35907           169911041  1.699110e+08  169911041.0  1.699110e+08
# 35908            14979215  1.497922e+07   14979215.0  1.497922e+07
# 35909           169911041  1.699110e+08  169911041.0  1.699110e+08
#
#           sweetness        tannin
# 0      1.782577e+00  3.415475e+00
# 1      1.782577e+00  3.415475e+00
# 2      1.782577e+00  3.415475e+00
# 3      1.782577e+00  3.415475e+00
# 4      1.838485e+00  3.483987e+00
# ...             ...           ...
# 35905  1.647843e+08  1.647843e+08
# 35906  1.497922e+07  1.497922e+07
# 35907  1.699110e+08  1.699110e+08
# 35908  1.497922e+07  1.497922e+07
# 35909  1.699110e+08  1.699110e+08
#
# [35910 rows x 11 columns]

# %% [markdown]
# ## Drop rows that have not information (in the scraping fase they where empty)

# %%
rows_drop = df[df['wine_id'] == df['body']].index

# %%
cleaned = df.drop(rows_drop)
print(df.shape[0] - len(rows_drop))
cleaned.shape
# Out:
# 31091
# (31091, 11)

# %% [markdown]
# ## Check NaNs

# %%
cleaned.isna().sum()
# Out:
# wine_id                    0
# varietal_name              0
# style_id                   0
# body                       0
# acidity_1                  0
# acidity_description        0
# acidity_2                  0
# fizziness              30965
# intensity                  0
# sweetness                  1
# tannin                 10993
# dtype: int64

# %%
cleaned[cleaned['fizziness']==0]
# Out:
# Empty DataFrame
# Columns: [wine_id, varietal_name, style_id, body, acidity_1, acidity_description, acidity_2, fizziness, intensity, sweetness, tannin]
# Index: []

# %% [markdown]
# ### Fill NaNs with 0 because I think it is the missing value

# %%
update = cleaned.fillna(0)

# %% [markdown]
# ## Round values

# %%
def rounded(df,cols):
    for col in cols:
        df[col] = round(df[col],2)
    return df

# %%
cols = ['acidity_2','fizziness','intensity','sweetness','tannin']
update = rounded(update,cols)
update
# Out:
#          wine_id              varietal_name  style_id  body  acidity_1  \
# 0        1420799  Tinto de Ribera del Duero       180     5          3
# 1        1199830  Tinto de Ribera del Duero       180     5          3
# 2        1494622  Tinto de Ribera del Duero       180     5          3
# 3        1229417  Tinto de Ribera del Duero       180     5          3
# 4       87412043  Tinto de Ribera del Duero       180     5          3
# ...          ...                        ...       ...   ...        ...
# 35867   61243167                   Riesling       186     2          3
# 35868  160177301              Grauburgunder       148     3          3
# 35869   61745791                   Riesling       186     2          3
# 35870  169349840                Pinot Blanc       141     3          3
# 35871  168904390                   Riesling       186     2          3
#
#       acidity_description  acidity_2  fizziness  intensity  sweetness  tannin
# 0                    Alta       3.70        0.0       3.84       1.78    3.42
# 1                    Alta       3.70        0.0       3.84       1.78    3.42
# 2                    Alta       3.70        0.0       3.84       1.78    3.42
# 3                    Alta       3.70        0.0       3.84       1.78    3.42
# 4                    Alta       3.67        0.0       3.85       1.84    3.48
# ...                   ...        ...        ...        ...        ...     ...
# 35867                Alta       4.19        0.0       2.64       1.89    0.00
# 35868                Alta       3.02        0.0       3.03       1.83    0.00
# 35869                Alta       4.63        0.0       2.90       1.58    0.00
# 35870                Alta       4.07        0.0       3.00       1.00    0.00
# 35871                Alta       4.12        0.0       2.74       1.40    0.00
#
# [31091 rows x 11 columns]

# %% [markdown]
# ## Check and drop duplicates

# %%
update.duplicated().sum()
# Out:
# 12793

# %%
update = update.drop_duplicates()
update.shape
# Out:
# (18298, 11)

# %%
update.duplicated(subset = ['wine_id']).sum()
# Out:
# 0

# %% [markdown]
# ## Check rows with missing information (i'll deal with them when importing from MySQL)

# %%
update[update['style_id']==update['body']]
# Out:
#          wine_id  varietal_name  style_id  body  acidity_1  \
# 21200  166990245  Pedro Ximenez       136   136        136
# 21809  156881629  Vino espumoso       216   216        216
# 21841  160211882  Vino espumoso       216   216        216
# 22008  169027400  Pedro Ximenez       136   136        136
# 22980  166331167  Vino espumoso       216   216        216
# 28331    3007729         Blanco       131   131        131
# 33549  164943039     Chardonnay        55    55         55
#
#       acidity_description  acidity_2  fizziness  intensity  sweetness  tannin
# 21200                 136      136.0      136.0      136.0      136.0   136.0
# 21809                 216      216.0      216.0      216.0      216.0   216.0
# 21841                 216      216.0      216.0      216.0      216.0   216.0
# 22008                 136      136.0      136.0      136.0      136.0   136.0
# 22980                 216      216.0      216.0      216.0      216.0   216.0
# 28331                 131      131.0      131.0      131.0      131.0   131.0
# 33549                  55       55.0       55.0       55.0       55.0    55.0

# %%
values = update[update['style_id']==update['body']]['wine_id'].values

# %%
update[update['wine_id'].isin(values)]
# Out:
#          wine_id  varietal_name  style_id  body  acidity_1  \
# 21200  166990245  Pedro Ximenez       136   136        136
# 21809  156881629  Vino espumoso       216   216        216
# 21841  160211882  Vino espumoso       216   216        216
# 22008  169027400  Pedro Ximenez       136   136        136
# 22980  166331167  Vino espumoso       216   216        216
# 28331    3007729         Blanco       131   131        131
# 33549  164943039     Chardonnay        55    55         55
#
#       acidity_description  acidity_2  fizziness  intensity  sweetness  tannin
# 21200                 136      136.0      136.0      136.0      136.0   136.0
# 21809                 216      216.0      216.0      216.0      216.0   216.0
# 21841                 216      216.0      216.0      216.0      216.0   216.0
# 22008                 136      136.0      136.0      136.0      136.0   136.0
# 22980                 216      216.0      216.0      216.0      216.0   216.0
# 28331                 131      131.0      131.0      131.0      131.0   131.0
# 33549                  55       55.0       55.0       55.0       55.0    55.0

# %% [markdown]
# ## Save csv

# %%
update.to_csv('update_style.csv',index=False)

# %% [markdown]
# ## Save MySQL

# %%
import pymysql
from sqlalchemy import create_engine
import getpass  # To get the password without showing the input
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:' + password + '@localhost/clean_winery'
engine = create_engine(connection_string)

# %%
update.to_sql('style', con = engine, if_exists = 'replace', index = False )
# Out:
# 18298

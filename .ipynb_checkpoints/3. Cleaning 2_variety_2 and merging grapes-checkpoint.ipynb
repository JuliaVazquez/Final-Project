# %% [markdown]
# # Import libraries and data

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
import pymysql
from sqlalchemy import create_engine
import getpass 
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:' + password + '@localhost/clean_winery'
engine = create_engine(connection_string)

# %% [markdown]
# ## Getting all the data

# %%
query = ''' SELECT d.wine_id, d.type, d.wine_name, d.country, w.region, d.varietal_name, w.winery, w.year, d.style_id, d.body, s.body_description, d.acidity_1, s.acidity_description, d.acidity_2, d.fizziness, d.intensity, d.sweetness, d.tannin, p.vol_ml, p.price_eur, w.num_ratings, w.rate FROM to_clean d
LEFT JOIN wine w USING (wine_id)
LEFT JOIN purchase p USING (wine_id)
LEFT JOIN style s USING (wine_id);'''

all_data = pd.read_sql(query, engine)

# %%
all_data.shape
# Out:
# (21076, 22)

# %%
new_wine = pd.read_csv('new_wines.csv')
new_grapes = pd.read_csv('new_grapes.csv')
new_purchase = pd.read_csv('new_purchase.csv')
new_style = pd.read_csv('new_style.csv')

print(new_wine.shape)
print(new_grapes.shape)
print(new_purchase.shape)
print(new_style.shape)
# Out:
# (219, 9)
# (219, 13)
# (218, 6)
# (219, 12)

# %%
new_1 = pd.merge(left = new_wine,
        right = new_style,
        how = 'inner', 
        left_on = "wine_id", 
        right_on= "wine_id")

# %%
new_1 = pd.merge(left = new_1,
        right = new_purchase,
        how = 'inner', 
        left_on = "wine_id", 
        right_on= "wine_id")

# %%
new_1.columns
# Out:
# Index(['wine_id', 'wine_name', 'winery', 'type', 'region', 'country', 'year',
#        'num_ratings', 'rate', 'varietal_name', 'style_id', 'body',
#        'body_description', 'acidity_1', 'acidity_description', 'acidity_2',
#        'fizziness', 'intensity', 'sweetness', 'tannin', 'price', 'currency',
#        'bottle_type_id', 'bottle_type', 'vol_ml'],
#       dtype='object')

# %%
new_1 = new_1.drop(['currency','bottle_type','bottle_type_id'],axis=1)
len(new_1.columns)
new_1.columns
# Out:
# Index(['wine_id', 'wine_name', 'winery', 'type', 'region', 'country', 'year',
#        'num_ratings', 'rate', 'varietal_name', 'style_id', 'body',
#        'body_description', 'acidity_1', 'acidity_description', 'acidity_2',
#        'fizziness', 'intensity', 'sweetness', 'tannin', 'price', 'vol_ml'],
#       dtype='object')

# %%
all_data.columns
# Out:
# Index(['wine_id', 'type', 'wine_name', 'country', 'region', 'varietal_name',
#        'winery', 'year', 'style_id', 'body', 'body_description', 'acidity_1',
#        'acidity_description', 'acidity_2', 'fizziness', 'intensity',
#        'sweetness', 'tannin', 'vol_ml', 'price_eur', 'num_ratings', 'rate'],
#       dtype='object')

# %%
new_1.columns = ['wine_id', 'wine_name', 'winery', 'type', 'region', 'country', 'year',
       'num_ratings', 'rate', 'varietal_name', 'style_id', 'body',
       'body_description', 'acidity_1', 'acidity_description', 'acidity_2',
       'fizziness', 'intensity', 'sweetness', 'tannin', 'price_eur', 'vol_ml']

# %%
new_1 = new_1[['wine_id', 'type', 'wine_name', 'country', 'region', 'varietal_name',
       'winery', 'year', 'style_id', 'body', 'body_description', 'acidity_1',
       'acidity_description', 'acidity_2', 'fizziness', 'intensity',
       'sweetness', 'tannin', 'vol_ml', 'price_eur', 'num_ratings', 'rate']]

# %%
new_1
# Out:
#        wine_id  type                                          wine_name  \
# 0    156213864     1                 Pago de Carraovejas El Anejón 2018
# 1      6206648     1                   Remírez de Ganuza Trasnocho 2012
# 2    156754898     1                 Jesus Madrazo Selección Rioja 2018
# 3    161998730     1  Viña al Lado de la Casa Altos de Las Gateras M...
# 4      5160035     1                       VALENCISO Rioja Reserva 2014
# ..         ...   ...                                                ...
# 213  157885098     2  Matrot La Quintessence Puligny Montrachet 1er ...
# 214  160211613     2  Domaine William Fèvre Chablis Premier Cru 'Mon...
# 215  131768262     2   Marcel Deiss Alsace Grand Cru Schoenenbourg 2016
# 216  157091023     2  Louis Jadot Chassagne Montrachet Grande Montag...
# 217  166510928     2  Pascal Jolivet Sancerre Les Caillottes Blanc 2020
#
#     country                            region              varietal_name  \
# 0     spain                  Ribera del Duero  Tinto de Ribera del Duero
# 1     spain                             Rioja             Tinto de Rioja
# 2     spain                             Rioja             Tinto de Rioja
# 3     spain                    Vino de España                 Monastrell
# 4     spain                             Rioja             Tinto de Rioja
# ..      ...                               ...                        ...
# 213  france    Puligny-Montrachet Premier Cru   Blanco de Côte de Beaune
# 214  france       Chablis 1er Cru "Montmains"                    Chablis
# 215  france                  Alsace Grand Cru                   Riesling
# 216  france  Chassagne-Montrachet Premier Cru   Blanco de Côte de Beaune
# 217  france                          Sancerre                     Blanco
#
#                       winery  year  style_id  body body_description  \
# 0        Pago de Carraovejas  2018       180     5  De mucho cuerpo
# 1          Remírez de Ganuza  2012       190     4  De mucho cuerpo
# 2              Jesus Madrazo  2018       190     4  De mucho cuerpo
# 3    Viña al Lado de la Casa  2018       121     5  De mucho cuerpo
# 4                  VALENCISO  2014       190     4  De mucho cuerpo
# ..                       ...   ...       ...   ...              ...
# 213                   Matrot  2017       285     4  De mucho cuerpo
# 214    Domaine William Fèvre  2019        49     4  De mucho cuerpo
# 215             Marcel Deiss  2016       181     4  De mucho cuerpo
# 216              Louis Jadot  2017       285     4  De mucho cuerpo
# 217           Pascal Jolivet  2020       235     4  De mucho cuerpo
#
#      acidity_1 acidity_description  acidity_2  fizziness  intensity  \
# 0            3                Alta   3.631428        NaN   3.931312
# 1            3                Alta   3.713929        NaN   4.061050
# 2            3                Alta   3.470833        NaN   3.773648
# 3            3                Alta   3.443636        NaN   3.875325
# 4            3                Alta   3.743715        NaN   3.799382
# ..         ...                 ...        ...        ...        ...
# 213          2               Media   3.088894        NaN   3.881213
# 214          3                Alta   4.006359        NaN   2.934199
# 215          3                Alta   4.353873        NaN   3.055827
# 216          2               Media   3.288851        NaN   3.683764
# 217          3                Alta   4.053228        NaN   2.176103
#
#      sweetness    tannin  vol_ml  price_eur  num_ratings  rate
# 0     2.043272  3.457241     750      87.95         6116   4.6
# 1     1.842217  3.772245     750     118.89         3205   4.5
# 2     1.594590  3.089358     750      32.00          386   4.3
# 3     1.429870  4.096407     750      45.00          192   4.4
# 4     1.724501  3.731516     750      19.90        11621   4.1
# ..         ...       ...     ...        ...          ...   ...
# 213   2.022191       NaN     750      82.50          282   4.2
# 214   1.350180       NaN     750      39.58         1908   4.0
# 215   3.027973       NaN     750      71.95         1651   4.3
# 216   1.558103       NaN     750      78.33          301   4.1
# 217   1.342828       NaN     750      23.33         1583   4.0
#
# [218 rows x 22 columns]

# %%
new_1 = new_1.fillna(0)

# %%
# Checking if I had duplicates

# %%
ids = new_1['wine_id'].values

# %%
all_data[all_data['wine_id'].isin(ids)]
# Out:
# Empty DataFrame
# Columns: [wine_id, type, wine_name, country, region, varietal_name, winery, year, style_id, body, body_description, acidity_1, acidity_description, acidity_2, fizziness, intensity, sweetness, tannin, vol_ml, price_eur, num_ratings, rate]
# Index: []

# %%
all_data = pd.concat([all_data,new_1],axis=0)

# %%
all_data
# Out:
#        wine_id  type                                          wine_name  \
# 0     27946372     1                     Paulo Laureano Dolium Reserva
# 1      5624201     1       Herdade do Rocim Grande Rocim Reserva Tinto
# 2      2020315     1                                Dona Maria Reserva
# 3    144779059     1             Paulo Laureano Bacalhau Escolha Tinto
# 4     13551606     1            Herdade do Menir Vale de Ancho Reserva
# ..         ...   ...                                                ...
# 213  157885098     2  Matrot La Quintessence Puligny Montrachet 1er ...
# 214  160211613     2  Domaine William Fèvre Chablis Premier Cru 'Mon...
# 215  131768262     2   Marcel Deiss Alsace Grand Cru Schoenenbourg 2016
# 216  157091023     2  Louis Jadot Chassagne Montrachet Grande Montag...
# 217  166510928     2  Pascal Jolivet Sancerre Les Caillottes Blanc 2020
#
#       country                            region             varietal_name  \
# 0    portugal                          Alentejo         Tinto de Alentejo
# 1    portugal                          Alentejo         Tinto de Alentejo
# 2    portugal                          Alentejo         Tinto de Alentejo
# 3    portugal                          Alentejo         Tinto de Alentejo
# 4    portugal                          Alentejo         Tinto de Alentejo
# ..        ...                               ...                       ...
# 213    france    Puligny-Montrachet Premier Cru  Blanco de Côte de Beaune
# 214    france       Chablis 1er Cru "Montmains"                   Chablis
# 215    france                  Alsace Grand Cru                  Riesling
# 216    france  Chassagne-Montrachet Premier Cru  Blanco de Côte de Beaune
# 217    france                          Sancerre                    Blanco
#
#                     winery  year  style_id  body body_description  acidity_1  \
# 0           Paulo Laureano  2014         2   4.0  De mucho cuerpo        3.0
# 1         Herdade do Rocim  2013         2   4.0  De mucho cuerpo        3.0
# 2               Dona Maria  2005         2   4.0  De mucho cuerpo        3.0
# 3           Paulo Laureano  2016         2   4.0  De mucho cuerpo        3.0
# 4         Herdade do Menir  2011         2   4.0  De mucho cuerpo        3.0
# ..                     ...   ...       ...   ...              ...        ...
# 213                 Matrot  2017       285   4.0  De mucho cuerpo        2.0
# 214  Domaine William Fèvre  2019        49   4.0  De mucho cuerpo        3.0
# 215           Marcel Deiss  2016       181   4.0  De mucho cuerpo        3.0
# 216            Louis Jadot  2017       285   4.0  De mucho cuerpo        2.0
# 217         Pascal Jolivet  2020       235   4.0  De mucho cuerpo        3.0
#
#     acidity_description  acidity_2  fizziness  intensity  sweetness  tannin  \
# 0                  Alta   3.360000        0.0   3.970000   1.670000    3.25
# 1                  Alta   3.000000        0.0   4.260000   2.140000    3.18
# 2                  Alta   2.980000        0.0   4.110000   1.730000    2.79
# 3                  Alta   2.880000        0.0   3.920000   1.640000    3.09
# 4                  Alta   3.020000        0.0   4.310000   2.210000    3.43
# ..                  ...        ...        ...        ...        ...     ...
# 213               Media   3.088894        0.0   3.881213   2.022191    0.00
# 214                Alta   4.006359        0.0   2.934199   1.350180    0.00
# 215                Alta   4.353873        0.0   3.055827   3.027973    0.00
# 216               Media   3.288851        0.0   3.683764   1.558103    0.00
# 217                Alta   4.053228        0.0   2.176103   1.342828    0.00
#
#      vol_ml  price_eur  num_ratings  rate
# 0     750.0      58.00          721   4.2
# 1     750.0      72.50         1256   4.2
# 2     750.0      42.00         3040   4.0
# 3     750.0      17.00          538   4.0
# 4     750.0      44.00          972   4.3
# ..      ...        ...          ...   ...
# 213   750.0      82.50          282   4.2
# 214   750.0      39.58         1908   4.0
# 215   750.0      71.95         1651   4.3
# 216   750.0      78.33          301   4.1
# 217   750.0      23.33         1583   4.0
#
# [21294 rows x 22 columns]

# %% [markdown]
# ## Dealing with duplicates and varieties

# %%
all_data.duplicated(subset = 'wine_id').sum()
# Out:
# 667

# %%
all_data['varietal_name'].value_counts()
# Out:
# Blanco                     4155
# Tinto                      2967
# Riesling                    963
# Tinto de Douro              746
# Chardonnay                  688
#                            ...
# Malbec - Syrah                2
# Chasselas                     1
# Merlot - Syrah                1
# Dornfelder                    1
# Chenin blanc - Viognier       1
# Name: varietal_name, Length: 117, dtype: int64

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Muscat','Muscadet', 'Moscatel - Chardonnay']),'Moscatel',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Pinot noir']),'Pinot Noir',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Petite Sirah']),'Syrah',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Pinot gris']),'Pinot Gris',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Pinot blanc']),'Pinot Blanc',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Blend blanco']),'Blanco',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Blend tinto']),'Tinto',all_data['varietal_name'])

# %% [markdown]
# #### changing the combinations of varietal types, to the first one

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Sauvignon Blanc - Muscat']),'Sauvignon Blanc',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Malbec - Syrah']),'Malbec',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Torrontés - Riesling']),'Torrontés',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Chardonnay - Pinot Noir']),'Chardonnay',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Cabernet - Syrah']),'Cabernet',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Syrah - Viognier']),'Syrah',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Cabernet - Malbec']),'Cabernet',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Merlot - Syrah']),'Merlot',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Chenin blanc - Viognier']),'Chenin blanc',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Cabernet - Shiraz']),'Cabernet',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Sauvignon blanc']),'Sauvignon Blanc',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Blend de Pinotage']),'Pinotage',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['ALbariño']),'Albariño',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Blanco de Côte Chalonnaise','Tinto de Côte Chalonnaise']),'Cote Chalonnaise',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Blanco de Côte de Beaune','Tinto de Côte de Beaune']),'Cote Beaune',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Blanco de Côte de Nuits','Tinto de Côte de Nuits']),'Cote Nuits',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Blanco de Rioja','Tinto de Rioja']),'Rioja',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Tinto de Graves']),'Tinto',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Tinto de Valpolicella']),'Tinto',all_data['varietal_name'])

# %%
all_data.groupby(['varietal_name']).agg({'wine_id':pd.Series.nunique}).reset_index().sort_values(by = 'wine_id',ascending=False).tail(30)
# Out:
#                    varietal_name  wine_id
# 36                     Hermitage       49
# 17                     Carménère       47
# 29                    Côte-Rotie       43
# 44                      Moscatel       40
# 42                    Monastrell       36
# 90                      Viognier       33
# 61                 Saint-Estèphe       32
# 31                          Gavi       32
# 62                  Saint-Joseph       28
# 43       Montepulciano d'Abruzzo       26
# 84                     Torrontés       25
# 26              Cote Chalonnaise       25
# 46                Müller Thurgau       22
# 28              Crozes-Hermitage       21
# 64                   Saint-Péray       17
# 11                       Bonarda       15
# 69                      Silvaner       12
# 88  Vino Nobile di Montepulciano       12
# 85                    Treixadura       12
# 60                       Ripasso       11
# 24                        Cornas        9
# 16                      Cannonau        8
# 79             Tinto de Libourne        7
# 49                 Pedro Ximenez        7
# 66                    Sangiovese        6
# 89                 Vino espumoso        4
# 37                         Jerez        3
# 87                     Vin Jaune        2
# 20                     Chasselas        1
# 30                    Dornfelder        1

# %% [markdown]
# ## Encoding acidity and description, just in case

# %%
all_data['acidity_description'].value_counts()
# Out:
# Alta     16265
# Media     1880
# Baja       244
# 216          3
# 136          2
# 55           1
# 131          1
# Name: acidity_description, dtype: int64

# %%
all_data['acidity_description'] = all_data['acidity_description'].map({'Alta':'High', 'Media':'Medium', 'Baja':'Low'})

# %%
all_data['acidity_description'].value_counts()
# Out:
# High      16265
# Medium     1880
# Low         244
# Name: acidity_description, dtype: int64

# %%
all_data['body_description'].value_counts()
# Out:
# De mucho cuerpo       11688
# De cuerpo medio        4763
# De poco cuerpo         1783
# De muy poco cuerpo      155
# 216                       3
# 136                       2
# 55                        1
# 131                       1
# Name: body_description, dtype: int64

# %%
all_data['body_description'] = all_data['body_description'].map({'De mucho cuerpo':'High', 'De cuerpo medio':'Medium', 'De poco cuerpo':'Low','De muy poco cuerpo':'Very low'})

# %%
all_data['body_description'].value_counts()
# Out:
# High        11688
# Medium       4763
# Low          1783
# Very low      155
# Name: body_description, dtype: int64

# %% [markdown]
# ## Again checking and cleaning region and varietal name columns

# %%
all_data['region'].value_counts()
# Out:
# Douro                                          982
# Stellenbosch                                   706
# Rioja                                          670
# Ribera del Duero                               574
# Pfalz                                          436
#                                               ...
# Colli di Salerno                                 1
# Pompeiano                                        1
# Tharros                                          1
# Cour-Cheverny                                    1
# Saint-Aubin 1er Cru "Derrière chez Édouard"      1
# Name: region, Length: 1015, dtype: int64

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Tinto de Alentejo','Tinto de Douro','Tinto de Montsant','Tinto de Dão','Tinto de Priorat','Tinto de Ribera del Duero','Tinto de Toro','Tinto de Châteauneuf-du-Pape']),'Tinto',all_data['varietal_name'])

# %%
all_data['varietal_name'].value_counts()
# Out:
# Tinto            5320
# Blanco           4161
# Riesling          963
# Chardonnay        691
# Rioja             673
#                  ...
# Vino espumoso       4
# Jerez               3
# Vin Jaune           2
# Chasselas           1
# Dornfelder          1
# Name: varietal_name, Length: 84, dtype: int64

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Blanco vinho verde']),'Vinho verde',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Blanco de Macônnais']),'Maconnais',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Tinto de Libourne']),'Libourne',all_data['varietal_name'])

# %%
all_data['region'] = np.where(all_data['region'].isin(['Vino Nobile di Montepulciano']),'Montepulciano',all_data['region'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Vino Nobile di Montepulciano']),'Sangiovese',all_data['varietal_name'])

# %%
all_data['region'] = np.where(all_data['region'].isin(["Montepulciano d'Abruzzo"]),'Abruzzo',all_data['region'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(["Montepulciano d'Abruzzo"]),'Montepulciano',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Saint-Joseph']),'Syrah',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Saint-Julien','Pessac-Léognan']),'Cabernet Sauvignon',all_data['varietal_name'])

# %%
all_data['varietal_name'] = np.where(all_data['varietal_name'].isin(['Saint-Émilion']),'Merlot',all_data['varietal_name'])

# %% [markdown]
# ## Giving name to the type column

# %%
all_data['type'].value_counts()
# Out:
# 1    11964
# 2     9330
# Name: type, dtype: int64

# %%
all_data['type'] = all_data['type'].map({1:'Red', 2:'White'})
all_data['type'].value_counts()
# Out:
# Red      11964
# White     9330
# Name: type, dtype: int64

# %% [markdown]
# ## Merging with grapes

# %%
grapes = pd.read_csv('update_grapes.csv')

# %%
grapes
# Out:
#          wine_id  grapes_1_id grapes_1_name grapes_1_seoname  grapes_1_count  \
# 0        1420799           19   Tempranillo      tempranillo          172842
# 1        1199830           19   Tempranillo      tempranillo          172842
# 2        1494622           19   Tempranillo      tempranillo          172842
# 3        1229417           19   Tempranillo      tempranillo          172842
# 4       87412043           19   Tempranillo      tempranillo          172842
# ...          ...          ...           ...              ...             ...
# 18240   61243167           15      Riesling         riesling          262136
# 18241  160177301           15      Riesling         riesling          262136
# 18242   61745791           15      Riesling         riesling          262136
# 18243  169349840           15      Riesling         riesling          262136
# 18244  168904390           15      Riesling         riesling          262136
#
#        grapes_2_id  grapes_2_name grapes_2_seoname  grapes_2_count  \
# 0              142       Garnacha         garnacha           58111
# 1              142       Garnacha         garnacha           58111
# 2              142       Garnacha         garnacha           58111
# 3              142       Garnacha         garnacha           58111
# 4              142       Garnacha         garnacha           58111
# ...            ...            ...              ...             ...
# 18240          299  Spätburgunder    spatburgunder           50164
# 18241          299  Spätburgunder    spatburgunder           50164
# 18242          299  Spätburgunder    spatburgunder           50164
# 18243          299  Spätburgunder    spatburgunder           50164
# 18244          299  Spätburgunder    spatburgunder           50164
#
#        grapes_3_id       grapes_3_name    grapes_3_seoname  grapes_3_count
# 0                2  Cabernet Sauvignon  cabernet-sauvignon          801751
# 1                2  Cabernet Sauvignon  cabernet-sauvignon          801751
# 2                2  Cabernet Sauvignon  cabernet-sauvignon          801751
# 3                2  Cabernet Sauvignon  cabernet-sauvignon          801751
# 4                2  Cabernet Sauvignon  cabernet-sauvignon          801751
# ...            ...                 ...                 ...             ...
# 18240          355      Weissburgunder      weissburgunder           33464
# 18241          355      Weissburgunder      weissburgunder           33464
# 18242          355      Weissburgunder      weissburgunder           33464
# 18243          355      Weissburgunder      weissburgunder           33464
# 18244          355      Weissburgunder      weissburgunder           33464
#
# [18245 rows x 13 columns]

# %%
new_grapes
# Out:
#        wine_id  grapes_1_id grapes_1_name grapes_1_seoname  grapes_1_count  \
# 0    156213864           19   Tempranillo      tempranillo          172842
# 1      6206648           19   Tempranillo      tempranillo          172842
# 2    156754898           19   Tempranillo      tempranillo          172842
# 3    161998730           19   Tempranillo      tempranillo          172842
# 4      5160035           19   Tempranillo      tempranillo          172842
# ..         ...          ...           ...              ...             ...
# 214  157885098           14    Pinot Noir       pinot-noir          572334
# 215  160211613           14    Pinot Noir       pinot-noir          572334
# 216  131768262           14    Pinot Noir       pinot-noir          572334
# 217  157091023           14    Pinot Noir       pinot-noir          572334
# 218  166510928           14    Pinot Noir       pinot-noir          572334
#
#      grapes_2_id grapes_2_name grapes_2_seoname  grapes_2_count  grapes_3_id  \
# 0            142      Garnacha         garnacha           58111            2
# 1            142      Garnacha         garnacha           58111            2
# 2            142      Garnacha         garnacha           58111            2
# 3            142      Garnacha         garnacha           58111            2
# 4            142      Garnacha         garnacha           58111            2
# ..           ...           ...              ...             ...          ...
# 214            5    Chardonnay       chardonnay          604208           10
# 215            5    Chardonnay       chardonnay          604208           10
# 216            5    Chardonnay       chardonnay          604208           10
# 217            5    Chardonnay       chardonnay          604208           10
# 218            5    Chardonnay       chardonnay          604208           10
#
#           grapes_3_name    grapes_3_seoname  grapes_3_count
# 0    Cabernet Sauvignon  cabernet-sauvignon          801751
# 1    Cabernet Sauvignon  cabernet-sauvignon          801751
# 2    Cabernet Sauvignon  cabernet-sauvignon          801751
# 3    Cabernet Sauvignon  cabernet-sauvignon          801751
# 4    Cabernet Sauvignon  cabernet-sauvignon          801751
# ..                  ...                 ...             ...
# 214              Merlot              merlot          566719
# 215              Merlot              merlot          566719
# 216              Merlot              merlot          566719
# 217              Merlot              merlot          566719
# 218              Merlot              merlot          566719
#
# [219 rows x 13 columns]

# %%
grapes = pd.concat([grapes,new_grapes],axis=0)

# %%
merged = pd.merge(left = all_data,
        right = grapes,
        how = 'left', 
        left_on = "wine_id", 
        right_on= "wine_id")

# %%
merged
# Out:
#          wine_id   type                                          wine_name  \
# 0       27946372    Red                     Paulo Laureano Dolium Reserva
# 1        5624201    Red       Herdade do Rocim Grande Rocim Reserva Tinto
# 2        2020315    Red                                Dona Maria Reserva
# 3      144779059    Red             Paulo Laureano Bacalhau Escolha Tinto
# 4       13551606    Red            Herdade do Menir Vale de Ancho Reserva
# ...          ...    ...                                                ...
# 21289  157885098  White  Matrot La Quintessence Puligny Montrachet 1er ...
# 21290  160211613  White  Domaine William Fèvre Chablis Premier Cru 'Mon...
# 21291  131768262  White   Marcel Deiss Alsace Grand Cru Schoenenbourg 2016
# 21292  157091023  White  Louis Jadot Chassagne Montrachet Grande Montag...
# 21293  166510928  White  Pascal Jolivet Sancerre Les Caillottes Blanc 2020
#
#         country                            region varietal_name  \
# 0      portugal                          Alentejo         Tinto
# 1      portugal                          Alentejo         Tinto
# 2      portugal                          Alentejo         Tinto
# 3      portugal                          Alentejo         Tinto
# 4      portugal                          Alentejo         Tinto
# ...         ...                               ...           ...
# 21289    france    Puligny-Montrachet Premier Cru   Cote Beaune
# 21290    france       Chablis 1er Cru "Montmains"       Chablis
# 21291    france                  Alsace Grand Cru      Riesling
# 21292    france  Chassagne-Montrachet Premier Cru   Cote Beaune
# 21293    france                          Sancerre        Blanco
#
#                       winery  year  style_id  body body_description  \
# 0             Paulo Laureano  2014         2   4.0             High
# 1           Herdade do Rocim  2013         2   4.0             High
# 2                 Dona Maria  2005         2   4.0             High
# 3             Paulo Laureano  2016         2   4.0             High
# 4           Herdade do Menir  2011         2   4.0             High
# ...                      ...   ...       ...   ...              ...
# 21289                 Matrot  2017       285   4.0             High
# 21290  Domaine William Fèvre  2019        49   4.0             High
# 21291           Marcel Deiss  2016       181   4.0             High
# 21292            Louis Jadot  2017       285   4.0             High
# 21293         Pascal Jolivet  2020       235   4.0             High
#
#        acidity_1 acidity_description  acidity_2  fizziness  intensity  \
# 0            3.0                High   3.360000        0.0   3.970000
# 1            3.0                High   3.000000        0.0   4.260000
# 2            3.0                High   2.980000        0.0   4.110000
# 3            3.0                High   2.880000        0.0   3.920000
# 4            3.0                High   3.020000        0.0   4.310000
# ...          ...                 ...        ...        ...        ...
# 21289        2.0              Medium   3.088894        0.0   3.881213
# 21290        3.0                High   4.006359        0.0   2.934199
# 21291        3.0                High   4.353873        0.0   3.055827
# 21292        2.0              Medium   3.288851        0.0   3.683764
# 21293        3.0                High   4.053228        0.0   2.176103
#
#        sweetness  tannin  vol_ml  price_eur  num_ratings  rate  grapes_1_id  \
# 0       1.670000    3.25   750.0      58.00          721   4.2         67.0
# 1       2.140000    3.18   750.0      72.50         1256   4.2         67.0
# 2       1.730000    2.79   750.0      42.00         3040   4.0         67.0
# 3       1.640000    3.09   750.0      17.00          538   4.0         67.0
# 4       2.210000    3.43   750.0      44.00          972   4.3         67.0
# ...          ...     ...     ...        ...          ...   ...          ...
# 21289   2.022191    0.00   750.0      82.50          282   4.2         14.0
# 21290   1.350180    0.00   750.0      39.58         1908   4.0         14.0
# 21291   3.027973    0.00   750.0      71.95         1651   4.3         14.0
# 21292   1.558103    0.00   750.0      78.33          301   4.1         14.0
# 21293   1.342828    0.00   750.0      23.33         1583   4.0         14.0
#
#           grapes_1_name  grapes_1_seoname  grapes_1_count  grapes_2_id  \
# 0      Touriga Nacional  touriga-nacional         85787.0         69.0
# 1      Touriga Nacional  touriga-nacional         85787.0         69.0
# 2      Touriga Nacional  touriga-nacional         85787.0         69.0
# 3      Touriga Nacional  touriga-nacional         85787.0         69.0
# 4      Touriga Nacional  touriga-nacional         85787.0         69.0
# ...                 ...               ...             ...          ...
# 21289        Pinot Noir        pinot-noir        572334.0          5.0
# 21290        Pinot Noir        pinot-noir        572334.0          5.0
# 21291        Pinot Noir        pinot-noir        572334.0          5.0
# 21292        Pinot Noir        pinot-noir        572334.0          5.0
# 21293        Pinot Noir        pinot-noir        572334.0          5.0
#
#       grapes_2_name grapes_2_seoname  grapes_2_count  grapes_3_id  \
# 0       Tinta Roriz      tinta-roriz         41047.0         68.0
# 1       Tinta Roriz      tinta-roriz         41047.0         68.0
# 2       Tinta Roriz      tinta-roriz         41047.0         68.0
# 3       Tinta Roriz      tinta-roriz         41047.0         68.0
# 4       Tinta Roriz      tinta-roriz         41047.0         68.0
# ...             ...              ...             ...          ...
# 21289    Chardonnay       chardonnay        604208.0         10.0
# 21290    Chardonnay       chardonnay        604208.0         10.0
# 21291    Chardonnay       chardonnay        604208.0         10.0
# 21292    Chardonnay       chardonnay        604208.0         10.0
# 21293    Chardonnay       chardonnay        604208.0         10.0
#
#         grapes_3_name grapes_3_seoname  grapes_3_count
# 0      Touriga Franca   touriga-franca         33763.0
# 1      Touriga Franca   touriga-franca         33763.0
# 2      Touriga Franca   touriga-franca         33763.0
# 3      Touriga Franca   touriga-franca         33763.0
# 4      Touriga Franca   touriga-franca         33763.0
# ...               ...              ...             ...
# 21289          Merlot           merlot        566719.0
# 21290          Merlot           merlot        566719.0
# 21291          Merlot           merlot        566719.0
# 21292          Merlot           merlot        566719.0
# 21293          Merlot           merlot        566719.0
#
# [21294 rows x 34 columns]

# %%
merged.isna().sum()
# Out:
# wine_id                   0
# type                      0
# wine_name                 0
# country                   0
# region                    0
# varietal_name             0
# winery                    0
# year                      0
# style_id                  0
# body                   2898
# body_description       2905
# acidity_1              2898
# acidity_description    2905
# acidity_2              2898
# fizziness              2898
# intensity              2898
# sweetness              2898
# tannin                 2898
# vol_ml                   50
# price_eur                50
# num_ratings               0
# rate                      0
# grapes_1_id            2829
# grapes_1_name          2829
# grapes_1_seoname       2829
# grapes_1_count         2829
# grapes_2_id            2829
# grapes_2_name          2829
# grapes_2_seoname       2829
# grapes_2_count         2829
# grapes_3_id            2829
# grapes_3_name          2829
# grapes_3_seoname       2829
# grapes_3_count         2829
# dtype: int64

# %%
merged['varietal_name'] = np.where(merged['varietal_name'].isin(['Blanco']),'White',merged['varietal_name'])
merged['varietal_name'] = np.where(merged['varietal_name'].isin(['Tinto']),'Red',merged['varietal_name'])

# %% [markdown]
# ### Saving changes, just in case

# %%
merged.to_csv('all_data.csv',index = False)
merged.to_sql('all_data', con = engine, if_exists = 'replace', index = False )
# Out:
# 21294

# %% [markdown]
# ## Checking and dealing with NaNs

# %%
merged.isna().sum()
# Out:
# wine_id                   0
# type                      0
# wine_name                 0
# country                   0
# region                    0
# varietal_name             0
# winery                    0
# year                      0
# style_id                  0
# body                   2898
# body_description       2905
# acidity_1              2898
# acidity_description    2905
# acidity_2              2898
# fizziness              2898
# intensity              2898
# sweetness              2898
# tannin                 2898
# vol_ml                   50
# price_eur                50
# num_ratings               0
# rate                      0
# grapes_1_id            2829
# grapes_1_name          2829
# grapes_1_seoname       2829
# grapes_1_count         2829
# grapes_2_id            2829
# grapes_2_name          2829
# grapes_2_seoname       2829
# grapes_2_count         2829
# grapes_3_id            2829
# grapes_3_name          2829
# grapes_3_seoname       2829
# grapes_3_count         2829
# dtype: int64

# %%
merged[merged['vol_ml'].isna()].head()
# Out:
#         wine_id   type                            wine_name   country  \
# 4990  161885318  White  Quinta da Romaneira Reserva Branco   portugal
# 4991  166633490  White          Quinta de Cidrô Chardonnay   portugal
# 4992  160556916  White    Quinta do Ortigao Arinto - Bical   portugal
# 5016  145918484  White                  CM Allgodao Branco   portugal
# 5031  163351371  White     Quinta dos Roques Dão Encruzado   portugal
#
#         region varietal_name               winery  year  style_id  body  \
# 4990     Douro         White  Quinta da Romaneira  2019       133   2.0
# 4991  Duriense         White      Quinta de Cidrô  2020       133   2.0
# 4992  Bairrada         White    Quinta do Ortigao  2018       133   2.0
# 5016       Dão         White                   CM  2015       133   2.0
# 5031       Dão         White    Quinta dos Roques  2020       133   2.0
#
#      body_description  acidity_1 acidity_description  acidity_2  fizziness  \
# 4990              Low        3.0                High       3.75        0.0
# 4991              Low        3.0                High       3.61        0.0
# 4992              Low        3.0                High       3.67        0.0
# 5016              Low        3.0                High       3.25        0.0
# 5031              Low        3.0                High       3.90        0.0
#
#       intensity  sweetness  tannin  vol_ml  price_eur  num_ratings  rate  \
# 4990       2.82       1.72     0.0     NaN        NaN          786   4.0
# 4991       3.08       1.83     0.0     NaN        NaN         3418   4.0
# 4992       3.31       1.44     0.0     NaN        NaN          390   3.8
# 5016       2.96       1.61     0.0     NaN        NaN          192   3.8
# 5031       3.02       1.64     0.0     NaN        NaN         1656   3.8
#
#       grapes_1_id     grapes_1_name  grapes_1_seoname  grapes_1_count  \
# 4990         67.0  Touriga Nacional  touriga-nacional         85787.0
# 4991         67.0  Touriga Nacional  touriga-nacional         85787.0
# 4992         67.0  Touriga Nacional  touriga-nacional         85787.0
# 5016         67.0  Touriga Nacional  touriga-nacional         85787.0
# 5031         67.0  Touriga Nacional  touriga-nacional         85787.0
#
#       grapes_2_id grapes_2_name grapes_2_seoname  grapes_2_count  grapes_3_id  \
# 4990         69.0   Tinta Roriz      tinta-roriz         41047.0         68.0
# 4991         69.0   Tinta Roriz      tinta-roriz         41047.0         68.0
# 4992         69.0   Tinta Roriz      tinta-roriz         41047.0         68.0
# 5016         69.0   Tinta Roriz      tinta-roriz         41047.0         68.0
# 5031         69.0   Tinta Roriz      tinta-roriz         41047.0         68.0
#
#        grapes_3_name grapes_3_seoname  grapes_3_count
# 4990  Touriga Franca   touriga-franca         33763.0
# 4991  Touriga Franca   touriga-franca         33763.0
# 4992  Touriga Franca   touriga-franca         33763.0
# 5016  Touriga Franca   touriga-franca         33763.0
# 5031  Touriga Franca   touriga-franca         33763.0

# %%
data_to_model = merged.drop(['wine_name','winery','vol_ml','price_eur'],axis=1)

# %%
data_to_model
# Out:
#          wine_id   type   country                            region  \
# 0       27946372    Red  portugal                          Alentejo
# 1        5624201    Red  portugal                          Alentejo
# 2        2020315    Red  portugal                          Alentejo
# 3      144779059    Red  portugal                          Alentejo
# 4       13551606    Red  portugal                          Alentejo
# ...          ...    ...       ...                               ...
# 21289  157885098  White    france    Puligny-Montrachet Premier Cru
# 21290  160211613  White    france       Chablis 1er Cru "Montmains"
# 21291  131768262  White    france                  Alsace Grand Cru
# 21292  157091023  White    france  Chassagne-Montrachet Premier Cru
# 21293  166510928  White    france                          Sancerre
#
#       varietal_name  year  style_id  body body_description  acidity_1  \
# 0               Red  2014         2   4.0             High        3.0
# 1               Red  2013         2   4.0             High        3.0
# 2               Red  2005         2   4.0             High        3.0
# 3               Red  2016         2   4.0             High        3.0
# 4               Red  2011         2   4.0             High        3.0
# ...             ...   ...       ...   ...              ...        ...
# 21289   Cote Beaune  2017       285   4.0             High        2.0
# 21290       Chablis  2019        49   4.0             High        3.0
# 21291      Riesling  2016       181   4.0             High        3.0
# 21292   Cote Beaune  2017       285   4.0             High        2.0
# 21293         White  2020       235   4.0             High        3.0
#
#       acidity_description  acidity_2  fizziness  intensity  sweetness  tannin  \
# 0                    High   3.360000        0.0   3.970000   1.670000    3.25
# 1                    High   3.000000        0.0   4.260000   2.140000    3.18
# 2                    High   2.980000        0.0   4.110000   1.730000    2.79
# 3                    High   2.880000        0.0   3.920000   1.640000    3.09
# 4                    High   3.020000        0.0   4.310000   2.210000    3.43
# ...                   ...        ...        ...        ...        ...     ...
# 21289              Medium   3.088894        0.0   3.881213   2.022191    0.00
# 21290                High   4.006359        0.0   2.934199   1.350180    0.00
# 21291                High   4.353873        0.0   3.055827   3.027973    0.00
# 21292              Medium   3.288851        0.0   3.683764   1.558103    0.00
# 21293                High   4.053228        0.0   2.176103   1.342828    0.00
#
#        num_ratings  rate  grapes_1_id     grapes_1_name  grapes_1_seoname  \
# 0              721   4.2         67.0  Touriga Nacional  touriga-nacional
# 1             1256   4.2         67.0  Touriga Nacional  touriga-nacional
# 2             3040   4.0         67.0  Touriga Nacional  touriga-nacional
# 3              538   4.0         67.0  Touriga Nacional  touriga-nacional
# 4              972   4.3         67.0  Touriga Nacional  touriga-nacional
# ...            ...   ...          ...               ...               ...
# 21289          282   4.2         14.0        Pinot Noir        pinot-noir
# 21290         1908   4.0         14.0        Pinot Noir        pinot-noir
# 21291         1651   4.3         14.0        Pinot Noir        pinot-noir
# 21292          301   4.1         14.0        Pinot Noir        pinot-noir
# 21293         1583   4.0         14.0        Pinot Noir        pinot-noir
#
#        grapes_1_count  grapes_2_id grapes_2_name grapes_2_seoname  \
# 0             85787.0         69.0   Tinta Roriz      tinta-roriz
# 1             85787.0         69.0   Tinta Roriz      tinta-roriz
# 2             85787.0         69.0   Tinta Roriz      tinta-roriz
# 3             85787.0         69.0   Tinta Roriz      tinta-roriz
# 4             85787.0         69.0   Tinta Roriz      tinta-roriz
# ...               ...          ...           ...              ...
# 21289        572334.0          5.0    Chardonnay       chardonnay
# 21290        572334.0          5.0    Chardonnay       chardonnay
# 21291        572334.0          5.0    Chardonnay       chardonnay
# 21292        572334.0          5.0    Chardonnay       chardonnay
# 21293        572334.0          5.0    Chardonnay       chardonnay
#
#        grapes_2_count  grapes_3_id   grapes_3_name grapes_3_seoname  \
# 0             41047.0         68.0  Touriga Franca   touriga-franca
# 1             41047.0         68.0  Touriga Franca   touriga-franca
# 2             41047.0         68.0  Touriga Franca   touriga-franca
# 3             41047.0         68.0  Touriga Franca   touriga-franca
# 4             41047.0         68.0  Touriga Franca   touriga-franca
# ...               ...          ...             ...              ...
# 21289        604208.0         10.0          Merlot           merlot
# 21290        604208.0         10.0          Merlot           merlot
# 21291        604208.0         10.0          Merlot           merlot
# 21292        604208.0         10.0          Merlot           merlot
# 21293        604208.0         10.0          Merlot           merlot
#
#        grapes_3_count
# 0             33763.0
# 1             33763.0
# 2             33763.0
# 3             33763.0
# 4             33763.0
# ...               ...
# 21289        566719.0
# 21290        566719.0
# 21291        566719.0
# 21292        566719.0
# 21293        566719.0
#
# [21294 rows x 30 columns]

# %%
data_to_model = data_to_model.dropna()
data_to_model.shape
# Out:
# (18389, 30)

# %%
data_to_model.isna().sum()
# Out:
# wine_id                0
# type                   0
# country                0
# region                 0
# varietal_name          0
# year                   0
# style_id               0
# body                   0
# body_description       0
# acidity_1              0
# acidity_description    0
# acidity_2              0
# fizziness              0
# intensity              0
# sweetness              0
# tannin                 0
# num_ratings            0
# rate                   0
# grapes_1_id            0
# grapes_1_name          0
# grapes_1_seoname       0
# grapes_1_count         0
# grapes_2_id            0
# grapes_2_name          0
# grapes_2_seoname       0
# grapes_2_count         0
# grapes_3_id            0
# grapes_3_name          0
# grapes_3_seoname       0
# grapes_3_count         0
# dtype: int64

# %% [markdown]
# ## Saving again the progress

# %%
data_to_model.to_csv('data_to_model.csv',index = False)
data_to_model.to_sql('data_to_model', con = engine, if_exists = 'replace', index = False )
# Out:
# 18389

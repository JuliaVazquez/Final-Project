# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
# %matplotlib inline

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

# %% [markdown]
# # Import data

# %%
pd.set_option('display.max_columns', None)

df = pd.read_csv('data_to_model.csv')
df
# Out:
#          wine_id type   country               region varietal_name  year  \
# 0       27946372  Red  portugal             Alentejo         Tinto  2014
# 1        5624201  Red  portugal             Alentejo         Tinto  2013
# 2        2020315  Red  portugal             Alentejo         Tinto  2005
# 3      144779059  Red  portugal             Alentejo         Tinto  2016
# 4       13551606  Red  portugal             Alentejo         Tinto  2011
# ...          ...  ...       ...                  ...           ...   ...
# 18280    3925832  Red    france  Châteauneuf-du-Pape         Tinto  2007
# 18281    3895726  Red    france  Châteauneuf-du-Pape         Tinto  1999
# 18282  155867259  Red    france  Châteauneuf-du-Pape         Tinto  2017
# 18283  150034283  Red    france  Châteauneuf-du-Pape         Tinto  2016
# 18284   17238979  Red    france  Châteauneuf-du-Pape         Tinto  2012
#
#        style_id  body  acidity_1 acidity_description  acidity_2  fizziness  \
# 0             2   4.0        3.0                High       3.36        0.0
# 1             2   4.0        3.0                High       3.00        0.0
# 2             2   4.0        3.0                High       2.98        0.0
# 3             2   4.0        3.0                High       2.88        0.0
# 4             2   4.0        3.0                High       3.02        0.0
# ...         ...   ...        ...                 ...        ...        ...
# 18280       301   5.0        2.0              Medium       3.11        0.0
# 18281       301   5.0        2.0              Medium       3.11        0.0
# 18282       301   5.0        2.0              Medium       3.20        0.0
# 18283       301   5.0        2.0              Medium       3.10        0.0
# 18284       301   5.0        2.0              Medium       3.08        0.0
#
#        intensity  sweetness  tannin  num_ratings  rate
# 0           3.97       1.67    3.25          721   4.2
# 1           4.26       2.14    3.18         1256   4.2
# 2           4.11       1.73    2.79         3040   4.0
# 3           3.92       1.64    3.09          538   4.0
# 4           4.31       2.21    3.43          972   4.3
# ...          ...        ...     ...          ...   ...
# 18280       4.65       1.77    2.90         5870   4.5
# 18281       4.65       1.77    2.90         5870   4.5
# 18282       4.79       2.12    2.97          778   4.2
# 18283       4.67       1.68    2.85        10429   4.2
# 18284       4.71       1.78    2.95          181   4.6
#
# [18285 rows x 17 columns]

# %% [markdown]
# ## Split, scale and encode

# %%
df.select_dtypes(object)
# Out:
#       type   country               region varietal_name  year  \
# 0      Red  portugal             Alentejo         Tinto  2014
# 1      Red  portugal             Alentejo         Tinto  2013
# 2      Red  portugal             Alentejo         Tinto  2005
# 3      Red  portugal             Alentejo         Tinto  2016
# 4      Red  portugal             Alentejo         Tinto  2011
# ...    ...       ...                  ...           ...   ...
# 18280  Red    france  Châteauneuf-du-Pape         Tinto  2007
# 18281  Red    france  Châteauneuf-du-Pape         Tinto  1999
# 18282  Red    france  Châteauneuf-du-Pape         Tinto  2017
# 18283  Red    france  Châteauneuf-du-Pape         Tinto  2016
# 18284  Red    france  Châteauneuf-du-Pape         Tinto  2012
#
#       acidity_description
# 0                    High
# 1                    High
# 2                    High
# 3                    High
# 4                    High
# ...                   ...
# 18280              Medium
# 18281              Medium
# 18282              Medium
# 18283              Medium
# 18284              Medium
#
# [18285 rows x 6 columns]

# %%
df.select_dtypes(np.number)
# Out:
#          wine_id  style_id  body  acidity_1  acidity_2  fizziness  intensity  \
# 0       27946372         2   4.0        3.0       3.36        0.0       3.97
# 1        5624201         2   4.0        3.0       3.00        0.0       4.26
# 2        2020315         2   4.0        3.0       2.98        0.0       4.11
# 3      144779059         2   4.0        3.0       2.88        0.0       3.92
# 4       13551606         2   4.0        3.0       3.02        0.0       4.31
# ...          ...       ...   ...        ...        ...        ...        ...
# 18280    3925832       301   5.0        2.0       3.11        0.0       4.65
# 18281    3895726       301   5.0        2.0       3.11        0.0       4.65
# 18282  155867259       301   5.0        2.0       3.20        0.0       4.79
# 18283  150034283       301   5.0        2.0       3.10        0.0       4.67
# 18284   17238979       301   5.0        2.0       3.08        0.0       4.71
#
#        sweetness  tannin  num_ratings  rate
# 0           1.67    3.25          721   4.2
# 1           2.14    3.18         1256   4.2
# 2           1.73    2.79         3040   4.0
# 3           1.64    3.09          538   4.0
# 4           2.21    3.43          972   4.3
# ...          ...     ...          ...   ...
# 18280       1.77    2.90         5870   4.5
# 18281       1.77    2.90         5870   4.5
# 18282       2.12    2.97          778   4.2
# 18283       1.68    2.85        10429   4.2
# 18284       1.78    2.95          181   4.6
#
# [18285 rows x 11 columns]

# %%
def get_clusters(df):

    #split numericals - categoricals
    X_cat = df.select_dtypes(object)
    X_num = df.select_dtypes(np.number)
    X_num = X_num.drop(['wine_id'],axis=1)

        
    #fit and transform scaling numericals MinMax
    X_num_mm = MinMaxScaler().fit_transform(X_num) 
    # convert to dataframe again
    X_num_mm = pd.DataFrame(X_num_mm,columns=X_num.columns).reset_index(drop=True) 

    
    
    #fit and transform scaling numericals Standard
    X_num_st = StandardScaler().fit_transform(X_num) 
    # convert to dataframe again
    X_num_st = pd.DataFrame(X_num_st,columns=X_num.columns).reset_index(drop=True) 
    
    
    
    #fit and transform encoding categoricals
    X_cat = X_cat.astype(str)
    onehot = OneHotEncoder(handle_unknown='error', drop='first').fit(X_cat) 

    cols = onehot.get_feature_names_out(input_features=X_cat.columns)
    X_cat_enc = onehot.transform(X_cat).toarray()    
    # convert to dataframe again
    X_cat_enc = pd.DataFrame(X_cat_enc,columns=cols).reset_index(drop=True)

    
    return X_num_mm, X_num_st, X_cat_enc

# %%
X_num_mm, X_num_st, X_cat_enc = get_clusters(df)

# %%
X_num_mm
# Out:
#        style_id  body  acidity_1  acidity_2  fizziness  intensity  sweetness  \
# 0      0.003300  0.75        1.0   0.557951        0.0     0.7425      0.334
# 1      0.003300  0.75        1.0   0.460916        0.0     0.8150      0.428
# 2      0.003300  0.75        1.0   0.455526        0.0     0.7775      0.346
# 3      0.003300  0.75        1.0   0.428571        0.0     0.7300      0.328
# 4      0.003300  0.75        1.0   0.466307        0.0     0.8275      0.442
# ...         ...   ...        ...        ...        ...        ...        ...
# 18280  0.990099  1.00        0.5   0.490566        0.0     0.9125      0.354
# 18281  0.990099  1.00        0.5   0.490566        0.0     0.9125      0.354
# 18282  0.990099  1.00        0.5   0.514825        0.0     0.9475      0.424
# 18283  0.990099  1.00        0.5   0.487871        0.0     0.9175      0.336
# 18284  0.990099  1.00        0.5   0.482480        0.0     0.9275      0.356
#
#        tannin  num_ratings      rate
# 0       0.650     0.003630  0.875000
# 1       0.636     0.006323  0.875000
# 2       0.558     0.015305  0.833333
# 3       0.618     0.002709  0.833333
# 4       0.686     0.004893  0.895833
# ...       ...          ...       ...
# 18280   0.580     0.029552  0.937500
# 18281   0.580     0.029552  0.937500
# 18282   0.594     0.003917  0.875000
# 18283   0.570     0.052504  0.875000
# 18284   0.590     0.000911  0.958333
#
# [18285 rows x 10 columns]

# %% [markdown]
# ## Check how many clusters

# %% [markdown]
# #### with minmax scaled data

# %%
# %%time

K = range(2, 35)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X_num_mm)
    inertia.append(kmeans.inertia_)


plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# CPU times: total: 3min 23s
# Wall time: 36.9 s
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
# %%time

K = range(2, 35)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X_num_mm)
    silhouette.append(silhouette_score(X_num_mm, kmeans.predict(X_num_mm)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette score showing the optimal k')
# Out:
# CPU times: total: 7min 49s
# Wall time: 2min 54s
# Text(0.5, 1.0, 'Silhouette score showing the optimal k')

# %%
# %%time

K = range(30, 40)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X_num_mm)
    silhouette.append(silhouette_score(X_num_mm, kmeans.predict(X_num_mm)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette score showing the optimal k')
# Out:
# CPU times: total: 2min 34s
# Wall time: 51.5 s
# Text(0.5, 1.0, 'Silhouette score showing the optimal k')

# %%
# I will use 36 clusters wnd the minmax scaled data

# %% [markdown]
# #### with standard scaled data

# %%
# %%time

K = range(2, 35)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X_num_st)
    inertia.append(kmeans.inertia_)


plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# CPU times: total: 3min 57s
# Wall time: 38.2 s
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
# %%time

K = range(2, 35)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X_num_st)
    silhouette.append(silhouette_score(X_num_st, kmeans.predict(X_num_st)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette score showing the optimal k')
# Out:
# CPU times: total: 8min 16s
# Wall time: 2min 47s
# Text(0.5, 1.0, 'Silhouette score showing the optimal k')

# %% [markdown]
# ## Making the clusters

# %%
kmeans = KMeans(n_clusters=36)
kmeans.fit(X_num_mm)
# Out:
# KMeans(n_clusters=36)

# %%
# Assigning the clusters:
clusters = kmeans.predict(X_num_mm)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0      702
# 1      251
# 2      920
# 3      497
# 4      757
# 5      884
# 6     1164
# 7      441
# 8      208
# 9      613
# 10     525
# 11      98
# 12     708
# 13     531
# 14     886
# 15     738
# 16     237
# 17     598
# 18     218
# 19     475
# 20     336
# 21     359
# 22     320
# 23     232
# 24     166
# 25      92
# 26     476
# 27     928
# 28     490
# 29     138
# 30     643
# 31    1298
# 32     365
# 33     366
# 34      59
# 35     566
# dtype: int64

# %%
# visualizing clusters with PCA
from sklearn.decomposition import PCA

# %%
pca = PCA()
pca.fit(X_num_mm)
# Out:
# PCA()

# %%
pca.explained_variance_ratio_.round(2)
# Out:
# array([0.43, 0.26, 0.13, 0.06, 0.05, 0.03, 0.02, 0.01, 0.01, 0.  ])

# %%
X_num_mm_pca = pca.transform(X_num_mm)

# %%
options, charts = plt.subplots(1, 2, figsize=(12, 6))

charts[0].scatter(X_num_mm_pca[:,0],X_num_mm_pca[:,1], c = clusters)
charts[1].scatter(X_num_mm_pca[:,0],X_num_mm_pca[:,2], c = clusters)
plt.show()

# %%
options, charts = plt.subplots(1, 2, figsize=(12, 6))

charts[0].scatter(X_num_mm_pca[:,1],X_num_mm_pca[:,2], c = clusters)
charts[1].scatter(X_num_mm_pca[:,2],X_num_mm_pca[:,3], c = clusters)
plt.show()

# %% [markdown]
# ## Get dataframe

# %%
df['clusters'] = clusters

# %%
df
# Out:
#          wine_id type   country               region varietal_name  year  \
# 0       27946372  Red  portugal             Alentejo         Tinto  2014
# 1        5624201  Red  portugal             Alentejo         Tinto  2013
# 2        2020315  Red  portugal             Alentejo         Tinto  2005
# 3      144779059  Red  portugal             Alentejo         Tinto  2016
# 4       13551606  Red  portugal             Alentejo         Tinto  2011
# ...          ...  ...       ...                  ...           ...   ...
# 18280    3925832  Red    france  Châteauneuf-du-Pape         Tinto  2007
# 18281    3895726  Red    france  Châteauneuf-du-Pape         Tinto  1999
# 18282  155867259  Red    france  Châteauneuf-du-Pape         Tinto  2017
# 18283  150034283  Red    france  Châteauneuf-du-Pape         Tinto  2016
# 18284   17238979  Red    france  Châteauneuf-du-Pape         Tinto  2012
#
#        style_id  body  acidity_1 acidity_description  acidity_2  fizziness  \
# 0             2   4.0        3.0                High       3.36        0.0
# 1             2   4.0        3.0                High       3.00        0.0
# 2             2   4.0        3.0                High       2.98        0.0
# 3             2   4.0        3.0                High       2.88        0.0
# 4             2   4.0        3.0                High       3.02        0.0
# ...         ...   ...        ...                 ...        ...        ...
# 18280       301   5.0        2.0              Medium       3.11        0.0
# 18281       301   5.0        2.0              Medium       3.11        0.0
# 18282       301   5.0        2.0              Medium       3.20        0.0
# 18283       301   5.0        2.0              Medium       3.10        0.0
# 18284       301   5.0        2.0              Medium       3.08        0.0
#
#        intensity  sweetness  tannin  num_ratings  rate  clusters
# 0           3.97       1.67    3.25          721   4.2        35
# 1           4.26       2.14    3.18         1256   4.2        35
# 2           4.11       1.73    2.79         3040   4.0        35
# 3           3.92       1.64    3.09          538   4.0        35
# 4           4.31       2.21    3.43          972   4.3        35
# ...          ...        ...     ...          ...   ...       ...
# 18280       4.65       1.77    2.90         5870   4.5        23
# 18281       4.65       1.77    2.90         5870   4.5        23
# 18282       4.79       2.12    2.97          778   4.2        23
# 18283       4.67       1.68    2.85        10429   4.2        23
# 18284       4.71       1.78    2.95          181   4.6        23
#
# [18285 rows x 18 columns]

# %% [markdown]
# ## Save new dataframe

# %%
import pymysql
from sqlalchemy import create_engine
import getpass 
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:' + password + '@localhost/clean_winery'
engine = create_engine(connection_string)

# %%
df.to_csv('clustered.csv',index = False)
df.to_sql('clustered', con = engine, if_exists = 'replace', index = False )
# Out:
# 18285
